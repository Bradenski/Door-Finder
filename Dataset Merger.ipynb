# %%
import os
import shutil
import yaml
import random
from pathlib import Path
from collections import defaultdict

class YOLODatasetMerger:
    def __init__(self, dataset1_path, dataset2_path, output_path, 
                 train_ratio=0.7, val_ratio=0.2, test_ratio=0.1, 
                 stratify_second_dataset=True, random_seed=42):
        self.dataset1_path = Path(dataset1_path)
        self.dataset2_path = Path(dataset2_path)
        self.output_path = Path(output_path)
        
        # Split ratios
        self.train_ratio = train_ratio
        self.val_ratio = val_ratio
        self.test_ratio = test_ratio
        self.stratify_second_dataset = stratify_second_dataset
        
        # Set random seed for reproducibility
        random.seed(random_seed)
        
        # Validate split ratios
        if abs(train_ratio + val_ratio + test_ratio - 1.0) > 0.001:
            raise ValueError("Split ratios must sum to 1.0")
        
        # Load data.yaml files if they exist
        self.data1 = self.load_yaml_safe(self.dataset1_path / "data.yml")
        self.data2 = self.load_yaml_safe(self.dataset2_path / "data.yml")
        
    def load_yaml_safe(self, yaml_path):
        """Load YAML configuration file safely"""
        if yaml_path.exists():
            with open(yaml_path, 'r') as file:
                return yaml.safe_load(file)
        else:
            print(f"Warning: {yaml_path} not found, using defaults")
            return {'names': ['object'], 'nc': 1}
    
    def create_output_structure(self):
        """Create output directory structure: split/images and split/labels"""
        splits = ['train', 'val', 'test']
        
        for split in splits:
            (self.output_path / split / 'images').mkdir(parents=True, exist_ok=True)
            (self.output_path / split / 'labels').mkdir(parents=True, exist_ok=True)
    
    def detect_dataset_structure(self, dataset_path):
        """Detect the structure of the dataset"""
        dataset_path = Path(dataset_path)
        
        # Check for different possible structures
        structures = {
            'images_labels_split': dataset_path / 'images' / 'train',
            'split_images_labels': dataset_path / 'train' / 'images', 
            'flat': dataset_path / 'images'
        }
        
        for structure_name, test_path in structures.items():
            if test_path.exists():
                print(f"Detected {structure_name} structure for {dataset_path.name}")
                return structure_name
        
        print(f"Could not detect structure for {dataset_path.name}")
        return None
    
    def get_all_images_from_dataset(self, dataset_path):
        """Get all images from a dataset, handling different structures"""
        images = []
        structure = self.detect_dataset_structure(dataset_path)
        
        if structure == 'images_labels_split':
            # Structure: dataset/images/train, dataset/labels/train
            splits = ['train', 'val', 'test']
            for split in splits:
                img_dir = dataset_path / 'images' / split
                label_dir = dataset_path / 'labels' / split
                if img_dir.exists():
                    images.extend(self.get_images_from_directory(img_dir, label_dir, split))
                    
        elif structure == 'split_images_labels':
            # Structure: dataset/train/images, dataset/train/labels
            splits = ['train', 'val', 'test']
            for split in splits:
                img_dir = dataset_path / split / 'images'
                label_dir = dataset_path / split / 'labels'
                if img_dir.exists():
                    images.extend(self.get_images_from_directory(img_dir, label_dir, split))
                    
        elif structure == 'flat':
            # Structure: dataset/images, dataset/labels (all in one folder)
            img_dir = dataset_path / 'images'
            label_dir = dataset_path / 'labels'
            if img_dir.exists():
                images.extend(self.get_images_from_directory(img_dir, label_dir, 'all'))
        else:
            print(f"Warning: Could not find images in {dataset_path}")
            
        return images
    
    def get_images_from_directory(self, img_dir, label_dir, split_name):
        """Get images and corresponding labels from a directory"""
        images = []
        
        for img_file in img_dir.glob('*'):
            if img_file.suffix.lower() in ['.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif']:
                # Look for corresponding label
                label_file = label_dir / f"{img_file.stem}.txt"
                
                images.append({
                    'image_path': img_file,
                    'label_path': label_file if label_file.exists() else None,
                    'original_split': split_name
                })
                
        return images
    
    def stratified_split(self, images_list, dataset_name):
        """Create stratified splits ensuring representative distribution"""
        total_images = len(images_list)
        
        if total_images == 0:
            return {'train': [], 'val': [], 'test': []}
        
        # Calculate split sizes
        train_size = max(1, int(total_images * self.train_ratio))
        val_size = max(1, int(total_images * self.val_ratio)) if total_images > 1 else 0
        test_size = total_images - train_size - val_size
        
        # Ensure we don't have negative test size
        if test_size < 0:
            val_size += test_size
            test_size = 0
            
        # For very small datasets, ensure at least some images in train
        if train_size == 0:
            train_size = 1
            val_size = max(0, val_size - 1)
        
        # Shuffle the images for random distribution
        shuffled_images = images_list.copy()
        random.shuffle(shuffled_images)
        
        # Create splits
        splits = {
            'train': shuffled_images[:train_size],
            'val': shuffled_images[train_size:train_size + val_size],
            'test': shuffled_images[train_size + val_size:] if test_size > 0 else []
        }
        
        print(f"\n{dataset_name} stratified split:")
        print(f"  Total images: {total_images}")
        print(f"  Train: {len(splits['train'])} images ({len(splits['train'])/total_images:.1%})")
        print(f"  Val: {len(splits['val'])} images ({len(splits['val'])/total_images:.1%})")
        print(f"  Test: {len(splits['test'])} images ({len(splits['test'])/total_images:.1%})")
        
        return splits
    
    def copy_images_to_split(self, image_data_list, target_split, dataset_prefix):
        """Copy images and labels to the target split directory"""
        dst_images = self.output_path / target_split / 'images'
        dst_labels = self.output_path / target_split / 'labels'
        
        for img_data in image_data_list:
            img_path = img_data['image_path']
            label_path = img_data['label_path']
            
            # Create new filename with dataset prefix to avoid conflicts
            new_img_name = f"{dataset_prefix}_{img_path.name}"
            new_img_path = dst_images / new_img_name
            
            # Copy image
            shutil.copy2(img_path, new_img_path)
            
            # Copy corresponding label if it exists
            if label_path and label_path.exists():
                new_label_path = dst_labels / f"{Path(new_img_name).stem}.txt"
                shutil.copy2(label_path, new_label_path)
                print(f"  Copied: {img_path.name} -> {target_split}/{new_img_name}")
            else:
                print(f"  Copied: {img_path.name} -> {target_split}/{new_img_name} (no label)")
    
    def create_merged_yaml(self):
        """Create merged data.yaml file"""
        # Get class names from the datasets
        class_names = self.data1.get('names', ['object'])
        if isinstance(class_names, dict):
            # Convert dict format {0: "class1", 1: "class2"} to list
            class_names = [class_names[i] for i in sorted(class_names.keys())]
        
        merged_data = {
            'path': str(self.output_path.absolute()),
            'train': 'train/images',
            'val': 'val/images', 
            'test': 'test/images',
            'nc': len(class_names),
            'names': class_names
        }
        
        # Save merged data.yaml
        yaml_path = self.output_path / 'data.yaml'
        with open(yaml_path, 'w') as f:
            yaml.dump(merged_data, f, default_flow_style=False)
        
        print(f"\nCreated merged data.yaml with {merged_data['nc']} class(es): {class_names}")
    
    def merge_datasets(self):
        """Main method to merge datasets with stratified splitting"""
        print("Starting dataset merge with stratified splitting...")
        print(f"Dataset 1 path: {self.dataset1_path}")
        print(f"Dataset 2 path: {self.dataset2_path}")
        print(f"Output path: {self.output_path}")
        
        # Create output directory structure
        self.create_output_structure()
        
        # Get all images from both datasets
        images1 = self.get_all_images_from_dataset(self.dataset1_path)
        images2 = self.get_all_images_from_dataset(self.dataset2_path)
        
        print(f"\nFound {len(images1)} images in Dataset 1")
        print(f"Found {len(images2)} images in Dataset 2")
        
        if len(images1) == 0 and len(images2) == 0:
            print("\nERROR: No images found in either dataset!")
            print("Please check your dataset paths and structures.")
            return
        
        # Create stratified splits for both datasets
        if self.stratify_second_dataset and len(images2) > 0:
            # Stratify the smaller, more representative dataset
            splits2 = self.stratified_split(images2, "Dataset 2 (Representative)")
            
            # Stratify the larger dataset too for consistency
            splits1 = self.stratified_split(images1, "Dataset 1 (Large)")
        else:
            # Use existing splits if stratification is disabled
            print("Using existing splits (stratification disabled)")
            splits1 = self.get_existing_splits(images1)
            splits2 = self.get_existing_splits(images2)
        
        # Copy images to their assigned splits
        print("\nCopying images to merged dataset...")
        for split in ['train', 'val', 'test']:
            if splits1[split]:
                self.copy_images_to_split(splits1[split], split, "ds1")
            if splits2[split]:
                self.copy_images_to_split(splits2[split], split, "ds2")
        
        # Create merged data.yaml
        self.create_merged_yaml()
        
        # Print final statistics
        self.print_final_stats()
        
        print(f"\nDataset merge completed! Output saved to: {self.output_path}")
    
    def get_existing_splits(self, images_list):
        """Group images by their existing splits"""
        splits = {'train': [], 'val': [], 'test': []}
        for img_data in images_list:
            original_split = img_data['original_split']
            if original_split == 'all':
                # If flat structure, distribute randomly
                return self.stratified_split(images_list, "Dataset (flat structure)")
            else:
                splits[original_split].append(img_data)
        return splits
    
    def print_final_stats(self):
        """Print final statistics about the merged dataset"""
        print("\n" + "="*50)
        print("FINAL MERGED DATASET STATISTICS")
        print("="*50)
        
        total_images = 0
        total_labels = 0
        
        for split in ['train', 'val', 'test']:
            img_path = self.output_path / split / 'images'
            label_path = self.output_path / split / 'labels'
            
            if img_path.exists():
                images = list(img_path.glob('*'))
                labels = list(label_path.glob('*.txt')) if label_path.exists() else []
                
                # Count images from each dataset
                ds1_images = len([img for img in images if img.name.startswith('ds1_')])
                ds2_images = len([img for img in images if img.name.startswith('ds2_')])
                
                total_images += len(images)
                total_labels += len(labels)
                
                print(f"{split.upper()}:")
                print(f"  Total: {len(images)} images, {len(labels)} labels")
                print(f"  Dataset 1: {ds1_images} images")
                print(f"  Dataset 2: {ds2_images} images")
                if len(images) > 0:
                    print(f"  Dataset 2 representation: {ds2_images/len(images):.1%}")
                print()
        
        print(f"OVERALL TOTAL: {total_images} images, {total_labels} labels")

# %%
merger = YOLODatasetMerger(
    dataset1_path="./doors_500_yolov8/",
    dataset2_path="./trunk_tools_yolov8/", 
    output_path="./merged_dataset_v2",
    train_ratio=0.75,       # 75% training (16 representative images)
    val_ratio=0.15,         # 15% validation (3 representative images)
    test_ratio=0.10,        # 10% testing (2 representative images)
    stratify_second_dataset=True,
    random_seed=42
)
merger.merge_datasets()
# Out:
# Starting dataset merge with stratified splitting...
# Dataset 1 path: doors_500_yolov8
# Dataset 2 path: trunk_tools_yolov8
# Output path: merged_dataset
# Detected split_images_labels structure for doors_500_yolov8
# Detected split_images_labels structure for trunk_tools_yolov8
#
# Found 960 images in Dataset 1
# Found 21 images in Dataset 2
#
# Dataset 2 (Representative) stratified split:
#   Total images: 21
#   Train: 15 images (71.4%)
#   Val: 3 images (14.3%)
#   Test: 3 images (14.3%)
#
# Dataset 1 (Large) stratified split:
#   Total images: 960
#   Train: 720 images (75.0%)
#   Val: 144 images (15.0%)
#   Test: 96 images (10.0%)
#
# Copying images to merged dataset...
#   Copied: 777_png.rf.7a675d633ea2d5b5818ea173c0d6c886.jpg -> train/ds1_777_png.rf.7a675d633ea2d5b5818ea173c0d6c886.jpg
#   Copied: 651_png.rf.38c294b0157c364d164904a1b3e88e1a.jpg -> train/ds1_651_png.rf.38c294b0157c364d164904a1b3e88e1a.jpg
#   Copied: 1107_png.rf.eefcd326588001598fbaa5839c790cf1.jpg -> train/ds1_1107_png.rf.eefcd326588001598fbaa5839c790cf1.jpg
#   Copied: 843_png.rf.8b7c60ca3edb8a0e479d1c5ca7a7737b.jpg -> train/ds1_843_png.rf.8b7c60ca3edb8a0e479d1c5ca7a7737b.jpg
#   Copied: 1106_png.rf.3ac53ea04a9d22e916205e7b70fc7a15.jpg -> train/ds1_1106_png.rf.3ac53ea04a9d22e916205e7b70fc7a15.jpg
#   Copied: 879_png.rf.4d32a88ee6364b0d8aaf1a46a7cd82d9.jpg -> train/ds1_879_png.rf.4d32a88ee6364b0d8aaf1a46a7cd82d9.jpg
#   Copied: 767_png.rf.2e3dd9473ddd3c8c92ecb455416b7f11.jpg -> train/ds1_767_png.rf.2e3dd9473ddd3c8c92ecb455416b7f11.jpg
#   Copied: 779_png.rf.1c64af426cdf526f424d5de51ee1aa58.jpg -> train/ds1_779_png.rf.1c64af426cdf526f424d5de51ee1aa58.jpg
#   Copied: 883_png.rf.d2ffa483548ee5d91d7b4feb4eb122cb.jpg -> train/ds1_883_png.rf.d2ffa483548ee5d91d7b4feb4eb122cb.jpg
#   Copied: 859_png.rf.478046a094d31b893e89ff36019a1e7c.jpg -> train/ds1_859_png.rf.478046a094d31b893e89ff36019a1e7c.jpg
#   Copied: 1091_png.rf.78f5db1950b9f5eeaba9728ecbd389d8.jpg -> train/ds1_1091_png.rf.78f5db1950b9f5eeaba9728ecbd389d8.jpg
#   Copied: 872_png.rf.a2df9f6fb40ac519578a924616976af6.jpg -> train/ds1_872_png.rf.a2df9f6fb40ac519578a924616976af6.jpg
#   Copied: 638_png.rf.b3ff11d8962700b4cacbbbff63281439.jpg -> train/ds1_638_png.rf.b3ff11d8962700b4cacbbbff63281439.jpg
#   Copied: 1030_png.rf.6d69afa1f572008473b74427c62cd4ff.jpg -> train/ds1_1030_png.rf.6d69afa1f572008473b74427c62cd4ff.jpg
#   Copied: 761_png.rf.a1903570e6f8d804f338acf3b116eaa5.jpg -> train/ds1_761_png.rf.a1903570e6f8d804f338acf3b116eaa5.jpg
#   Copied: 779_png.rf.a8f3725dd6e695956954ed95e9543a67.jpg -> train/ds1_779_png.rf.a8f3725dd6e695956954ed95e9543a67.jpg
#   Copied: 1106_png.rf.6f32547a52978fec7761d5d1d5b1d199.jpg -> train/ds1_1106_png.rf.6f32547a52978fec7761d5d1d5b1d199.jpg
#   Copied: 1019_png.rf.2b2bab44b5b71d5ac7ed8262be92c35b.jpg -> train/ds1_1019_png.rf.2b2bab44b5b71d5ac7ed8262be92c35b.jpg
#   Copied: 674_png.rf.40a8323b286483161c4174e2716dcc92.jpg -> train/ds1_674_png.rf.40a8323b286483161c4174e2716dcc92.jpg
#   Copied: 733_png.rf.0925cd01652d6e7bd6eeedb6bbe527e9.jpg -> train/ds1_733_png.rf.0925cd01652d6e7bd6eeedb6bbe527e9.jpg
#   Copied: 783_png.rf.2f461e97f0c4026d74d3473b1e3d368b.jpg -> train/ds1_783_png.rf.2f461e97f0c4026d74d3473b1e3d368b.jpg
#   Copied: 785_png.rf.11c5d687bd5de40dea1236a39faa2dc9.jpg -> train/ds1_785_png.rf.11c5d687bd5de40dea1236a39faa2dc9.jpg
#   Copied: 1113_png.rf.bb1226fb697f853d2e27b19ea4e705b2.jpg -> train/ds1_1113_png.rf.bb1226fb697f853d2e27b19ea4e705b2.jpg
#   Copied: 894_png.rf.3187fd5c131f4304ee1c105fad2b8a8e.jpg -> train/ds1_894_png.rf.3187fd5c131f4304ee1c105fad2b8a8e.jpg
#   Copied: 1044_png.rf.7eec9d9ab59f419ea104c6348ce9acd8.jpg -> train/ds1_1044_png.rf.7eec9d9ab59f419ea104c6348ce9acd8.jpg
#   Copied: 819_png.rf.a7651b550a6d8f05c883d40fb34bfbc3.jpg -> train/ds1_819_png.rf.a7651b550a6d8f05c883d40fb34bfbc3.jpg
#   Copied: 916_png.rf.a9ef3d916e40f27625acd513ea481045.jpg -> train/ds1_916_png.rf.a9ef3d916e40f27625acd513ea481045.jpg
#   Copied: 916_png.rf.64a5c7c08ed653edf9f807ecda252c26.jpg -> train/ds1_916_png.rf.64a5c7c08ed653edf9f807ecda252c26.jpg
#   Copied: 958_png.rf.c2774c5b29d1deef9db7aefa2abe8606.jpg -> train/ds1_958_png.rf.c2774c5b29d1deef9db7aefa2abe8606.jpg
#   Copied: 781_png.rf.5771175c3cd4915e1f4b78a9598cb972.jpg -> train/ds1_781_png.rf.5771175c3cd4915e1f4b78a9598cb972.jpg
#   Copied: 1033_png.rf.df1b9947dc075f9e25f5cb220cdb14d2.jpg -> train/ds1_1033_png.rf.df1b9947dc075f9e25f5cb220cdb14d2.jpg
#   Copied: 1125_png.rf.a2607c9648cbaa0dc78bcf28e463debd.jpg -> train/ds1_1125_png.rf.a2607c9648cbaa0dc78bcf28e463debd.jpg
#   Copied: 862_png.rf.f109f5a2b36825eb5635bad4fadd7024.jpg -> train/ds1_862_png.rf.f109f5a2b36825eb5635bad4fadd7024.jpg
#   Copied: 848_png.rf.f0e66beb61e49215ea12b45247100123.jpg -> train/ds1_848_png.rf.f0e66beb61e49215ea12b45247100123.jpg
#   Copied: 835_png.rf.fa7c717df01f83f27e2d369979d3d4f0.jpg -> train/ds1_835_png.rf.fa7c717df01f83f27e2d369979d3d4f0.jpg
#   Copied: 711_png.rf.8b1642ee806c95950da313be9bb241e5.jpg -> train/ds1_711_png.rf.8b1642ee806c95950da313be9bb241e5.jpg
#   Copied: 1127_png.rf.106c33b50759e2b6f6cff80cfd05dfc0.jpg -> train/ds1_1127_png.rf.106c33b50759e2b6f6cff80cfd05dfc0.jpg
#   Copied: 1031_png.rf.cef1271feb30cc77159c2db9636d5d7d.jpg -> train/ds1_1031_png.rf.cef1271feb30cc77159c2db9636d5d7d.jpg
#   Copied: 706_png.rf.f24fa4dafe3c5a0f2ba10513968db186.jpg -> train/ds1_706_png.rf.f24fa4dafe3c5a0f2ba10513968db186.jpg
#   Copied: 781_png.rf.5921158f5e4de68a12120f80ee54118b.jpg -> train/ds1_781_png.rf.5921158f5e4de68a12120f80ee54118b.jpg
#   Copied: 666_png.rf.003e422090d7aac93473049e82438671.jpg -> train/ds1_666_png.rf.003e422090d7aac93473049e82438671.jpg
#   Copied: 781_png.rf.5103129add35e04fe4f2965199020367.jpg -> train/ds1_781_png.rf.5103129add35e04fe4f2965199020367.jpg
#   Copied: 944_png.rf.7e99291e372c01f264b07908170257e2.jpg -> train/ds1_944_png.rf.7e99291e372c01f264b07908170257e2.jpg
#   Copied: 692_png.rf.fa7ddff67da52f129df1ccc57c6dc7dc.jpg -> train/ds1_692_png.rf.fa7ddff67da52f129df1ccc57c6dc7dc.jpg
#   Copied: 682_png.rf.7e4dcc0e7903ed5fbbd4c2577715cf2e.jpg -> train/ds1_682_png.rf.7e4dcc0e7903ed5fbbd4c2577715cf2e.jpg
#   Copied: 686_png.rf.665c6af8a68a344836ea40c6c38f3fc4.jpg -> train/ds1_686_png.rf.665c6af8a68a344836ea40c6c38f3fc4.jpg
#   Copied: 956_png.rf.cb64acd290e9aeb3ca51232e4455bb7d.jpg -> train/ds1_956_png.rf.cb64acd290e9aeb3ca51232e4455bb7d.jpg
#   Copied: 642_png.rf.038618555fd381a3183d043fb85521b7.jpg -> train/ds1_642_png.rf.038618555fd381a3183d043fb85521b7.jpg
#   Copied: 1131_png.rf.889e86c58154e49afcedfccd5c2d757f.jpg -> train/ds1_1131_png.rf.889e86c58154e49afcedfccd5c2d757f.jpg
#   Copied: 751_png.rf.53b5018656e3bc2a23dc8ffb802197f6.jpg -> train/ds1_751_png.rf.53b5018656e3bc2a23dc8ffb802197f6.jpg
#   Copied: 880_png.rf.ad8dcc94b80a66a13b0db310d4b0c028.jpg -> train/ds1_880_png.rf.ad8dcc94b80a66a13b0db310d4b0c028.jpg
#   Copied: 786_png.rf.0f02153e4c56ebde67d26deb18fb91b8.jpg -> train/ds1_786_png.rf.0f02153e4c56ebde67d26deb18fb91b8.jpg
#   Copied: 1112_png.rf.0ad25e1a3585764550c328a0c374da1b.jpg -> train/ds1_1112_png.rf.0ad25e1a3585764550c328a0c374da1b.jpg
#   Copied: 831_png.rf.a16b8418e62198f7e020277778551c5b.jpg -> train/ds1_831_png.rf.a16b8418e62198f7e020277778551c5b.jpg
#   Copied: 939_png.rf.60c3f198be5fc170b7c5f70c45928642.jpg -> train/ds1_939_png.rf.60c3f198be5fc170b7c5f70c45928642.jpg
#   Copied: 654_png.rf.e8cef5997840da6e3452b482b84898ad.jpg -> train/ds1_654_png.rf.e8cef5997840da6e3452b482b84898ad.jpg
#   Copied: 732_png.rf.57358390943095ac64e59ed31205d536.jpg -> train/ds1_732_png.rf.57358390943095ac64e59ed31205d536.jpg
#   Copied: 835_png.rf.bfa7e1b29f9e3726b034cf114896c7cb.jpg -> train/ds1_835_png.rf.bfa7e1b29f9e3726b034cf114896c7cb.jpg
#   Copied: 731_png.rf.adb33c8d4eba8d10c46b8e223ef6785c.jpg -> train/ds1_731_png.rf.adb33c8d4eba8d10c46b8e223ef6785c.jpg
#   Copied: 1011_png.rf.ca4fae9006dc8ce89ae6023ac23ff4ce.jpg -> train/ds1_1011_png.rf.ca4fae9006dc8ce89ae6023ac23ff4ce.jpg
#   Copied: 653_png.rf.26b9e6d42cf73ecf710d82c20fcd5c36.jpg -> train/ds1_653_png.rf.26b9e6d42cf73ecf710d82c20fcd5c36.jpg
#   Copied: 1058_png.rf.91ecbd3b6f4e2729c027839fd80ba68f.jpg -> train/ds1_1058_png.rf.91ecbd3b6f4e2729c027839fd80ba68f.jpg
#   Copied: 883_png.rf.7f04aff06c652f265dc3fad0220ab32c.jpg -> train/ds1_883_png.rf.7f04aff06c652f265dc3fad0220ab32c.jpg
#   Copied: 994_png.rf.f378721a29de05b6425f15b8bea5eaa5.jpg -> train/ds1_994_png.rf.f378721a29de05b6425f15b8bea5eaa5.jpg
#   Copied: 724_png.rf.f0166d33ad2c9d83f0c4fd92da4ad8b3.jpg -> train/ds1_724_png.rf.f0166d33ad2c9d83f0c4fd92da4ad8b3.jpg
#   Copied: 1008_png.rf.8d0d7bea115c59e76d740d483231c300.jpg -> train/ds1_1008_png.rf.8d0d7bea115c59e76d740d483231c300.jpg
#   Copied: 1000_png.rf.4c164238b154a53faf4800ed2a91c9b7.jpg -> train/ds1_1000_png.rf.4c164238b154a53faf4800ed2a91c9b7.jpg
#   Copied: 1023_png.rf.dc5273b1381c49c31feacf585f1ffe34.jpg -> train/ds1_1023_png.rf.dc5273b1381c49c31feacf585f1ffe34.jpg
#   Copied: 1117_png.rf.d6674f87d9483e5305c1fdd92e3f6ed9.jpg -> train/ds1_1117_png.rf.d6674f87d9483e5305c1fdd92e3f6ed9.jpg
#   Copied: 644_png.rf.f68331f55600d131584c1d9eb0426843.jpg -> train/ds1_644_png.rf.f68331f55600d131584c1d9eb0426843.jpg
#   Copied: 709_png.rf.e7061acbf27d328d556d8b5d6001d3dd.jpg -> train/ds1_709_png.rf.e7061acbf27d328d556d8b5d6001d3dd.jpg
#   Copied: 771_png.rf.fb4e7aa4b27ecc26bb5ed5586eb0ae0c.jpg -> train/ds1_771_png.rf.fb4e7aa4b27ecc26bb5ed5586eb0ae0c.jpg
#   Copied: 944_png.rf.18f0e641597a7fa8465594a2239f9bb4.jpg -> train/ds1_944_png.rf.18f0e641597a7fa8465594a2239f9bb4.jpg
#   Copied: 865_png.rf.93b3b24797e813b98bbc8f6006771637.jpg -> train/ds1_865_png.rf.93b3b24797e813b98bbc8f6006771637.jpg
#   Copied: 807_png.rf.51960b514d1179fe8b9332a134287890.jpg -> train/ds1_807_png.rf.51960b514d1179fe8b9332a134287890.jpg
#   Copied: 697_png.rf.987fe7227da6a799c0f821d6151f9d70.jpg -> train/ds1_697_png.rf.987fe7227da6a799c0f821d6151f9d70.jpg
#   Copied: 694_png.rf.7f3ff2043d51cb10f47bcad6826a2935.jpg -> train/ds1_694_png.rf.7f3ff2043d51cb10f47bcad6826a2935.jpg
#   Copied: 741_png.rf.965b26fa71e3e323112c8d377206bf99.jpg -> train/ds1_741_png.rf.965b26fa71e3e323112c8d377206bf99.jpg
#   Copied: 1121_png.rf.f16dc75001ba244cf4d18515dc627c91.jpg -> train/ds1_1121_png.rf.f16dc75001ba244cf4d18515dc627c91.jpg
#   Copied: 966_png.rf.2f09dd5ec9d7a890ffb91654b0b737a9.jpg -> train/ds1_966_png.rf.2f09dd5ec9d7a890ffb91654b0b737a9.jpg
#   Copied: 1051_png.rf.bdf9bfb6f22c1de49079ac2fd008b6f9.jpg -> train/ds1_1051_png.rf.bdf9bfb6f22c1de49079ac2fd008b6f9.jpg
#   Copied: 703_png.rf.46e1dc13dc5cfdb799a60853457c444b.jpg -> train/ds1_703_png.rf.46e1dc13dc5cfdb799a60853457c444b.jpg
#   Copied: 1088_png.rf.11f340d5afdd0a738af477faeecb2e1e.jpg -> train/ds1_1088_png.rf.11f340d5afdd0a738af477faeecb2e1e.jpg
#   Copied: 836_png.rf.c061353a768d6219eed59a7a6f345f65.jpg -> train/ds1_836_png.rf.c061353a768d6219eed59a7a6f345f65.jpg
#   Copied: 931_png.rf.0bff2d50a544424685e60c1218ec162e.jpg -> train/ds1_931_png.rf.0bff2d50a544424685e60c1218ec162e.jpg
#   Copied: 1015_png.rf.1a2b77850eddd5c70d49d8a98fcd62cb.jpg -> train/ds1_1015_png.rf.1a2b77850eddd5c70d49d8a98fcd62cb.jpg
#   Copied: 891_png.rf.fe9ea05f4e1628b8ece82cb7eda23df2.jpg -> train/ds1_891_png.rf.fe9ea05f4e1628b8ece82cb7eda23df2.jpg
#   Copied: 785_png.rf.cca4ce89b11d73429f13025c3f33d50e.jpg -> train/ds1_785_png.rf.cca4ce89b11d73429f13025c3f33d50e.jpg
#   Copied: 815_png.rf.d3f4260efd8113726363724159571bed.jpg -> train/ds1_815_png.rf.d3f4260efd8113726363724159571bed.jpg
#   Copied: 697_png.rf.aea18b064c8a7698a1a6e9efd53f6074.jpg -> train/ds1_697_png.rf.aea18b064c8a7698a1a6e9efd53f6074.jpg
#   Copied: 1019_png.rf.544ecd5aa296cb453498e827be1d14cb.jpg -> train/ds1_1019_png.rf.544ecd5aa296cb453498e827be1d14cb.jpg
#   Copied: 951_png.rf.81df4ecb04ee387d1658b47f6d48937f.jpg -> train/ds1_951_png.rf.81df4ecb04ee387d1658b47f6d48937f.jpg
#   Copied: 641_png.rf.8356dcd71532dd3b6384c30e38bd1cd4.jpg -> train/ds1_641_png.rf.8356dcd71532dd3b6384c30e38bd1cd4.jpg
#   Copied: 704_png.rf.ee76ab860054e2ad3dd7d8e00147e24d.jpg -> train/ds1_704_png.rf.ee76ab860054e2ad3dd7d8e00147e24d.jpg
#   Copied: 973_png.rf.823d1983b9743a74c5e5bb285d583e5c.jpg -> train/ds1_973_png.rf.823d1983b9743a74c5e5bb285d583e5c.jpg
#   Copied: 808_png.rf.cbffe01a85ce09e6387a1ef928d08f51.jpg -> train/ds1_808_png.rf.cbffe01a85ce09e6387a1ef928d08f51.jpg
#   Copied: 1047_png.rf.3226be78884d40d2aa218a6a5dd3dd79.jpg -> train/ds1_1047_png.rf.3226be78884d40d2aa218a6a5dd3dd79.jpg
#   Copied: 761_png.rf.948143276555c910361edfc11a625c83.jpg -> train/ds1_761_png.rf.948143276555c910361edfc11a625c83.jpg
#   Copied: 1079_png.rf.da4a169703e4ed3edf7710db84a8686b.jpg -> train/ds1_1079_png.rf.da4a169703e4ed3edf7710db84a8686b.jpg
#   Copied: 1118_png.rf.74c12c038a6e5826c82fe217cacf0bda.jpg -> train/ds1_1118_png.rf.74c12c038a6e5826c82fe217cacf0bda.jpg
#   Copied: 750_png.rf.17eedaecc0e2ecde35a8b1cc7e88ab53.jpg -> train/ds1_750_png.rf.17eedaecc0e2ecde35a8b1cc7e88ab53.jpg
#   Copied: 1056_png.rf.433862a34d6409b516a8b5c8b3714bd0.jpg -> train/ds1_1056_png.rf.433862a34d6409b516a8b5c8b3714bd0.jpg
#   Copied: 782_png.rf.329cd30dc4fca6fa7384a4c53cef3d38.jpg -> train/ds1_782_png.rf.329cd30dc4fca6fa7384a4c53cef3d38.jpg
#   Copied: 856_png.rf.daa7c213e45f988ec182927b39c10865.jpg -> train/ds1_856_png.rf.daa7c213e45f988ec182927b39c10865.jpg
#   Copied: 711_png.rf.9e723b5bcb98cabfd5ed0a45bf26ea4c.jpg -> train/ds1_711_png.rf.9e723b5bcb98cabfd5ed0a45bf26ea4c.jpg
#   Copied: 905_png.rf.ff4fe12002c115630821888a605b1123.jpg -> train/ds1_905_png.rf.ff4fe12002c115630821888a605b1123.jpg
#   Copied: 864_png.rf.669134ee2767e4382585f665aa6e626b.jpg -> train/ds1_864_png.rf.669134ee2767e4382585f665aa6e626b.jpg
#   Copied: 951_png.rf.e9dc49602f156f819cccd74705dc8694.jpg -> train/ds1_951_png.rf.e9dc49602f156f819cccd74705dc8694.jpg
#   Copied: 681_png.rf.2270e0a8dafbf832d6f10800bf8a5041.jpg -> train/ds1_681_png.rf.2270e0a8dafbf832d6f10800bf8a5041.jpg
#   Copied: 1016_png.rf.aad75adbbaa82e23d3c83c7db0913546.jpg -> train/ds1_1016_png.rf.aad75adbbaa82e23d3c83c7db0913546.jpg
#   Copied: 698_png.rf.ee7ee3c1a690299445de763044c9f3fa.jpg -> train/ds1_698_png.rf.ee7ee3c1a690299445de763044c9f3fa.jpg
#   Copied: 980_png.rf.78462dd92682d8ab0c85f9edd2f1c9ac.jpg -> train/ds1_980_png.rf.78462dd92682d8ab0c85f9edd2f1c9ac.jpg
#   Copied: 680_png.rf.3d311314ed25fd7f970c1717fcb10868.jpg -> train/ds1_680_png.rf.3d311314ed25fd7f970c1717fcb10868.jpg
#   Copied: 1126_png.rf.540ed0763597982aecabc52a4bf00942.jpg -> train/ds1_1126_png.rf.540ed0763597982aecabc52a4bf00942.jpg
#   Copied: 952_png.rf.eb76e0193fc7cc4d08357edea70cea96.jpg -> train/ds1_952_png.rf.eb76e0193fc7cc4d08357edea70cea96.jpg
#   Copied: 727_png.rf.48649edb25052ae35d6fd06308a58c51.jpg -> train/ds1_727_png.rf.48649edb25052ae35d6fd06308a58c51.jpg
#   Copied: 848_png.rf.7840d067ff496da9fc6926de8349ce3b.jpg -> train/ds1_848_png.rf.7840d067ff496da9fc6926de8349ce3b.jpg
#   Copied: 1087_png.rf.faf77dc6bc7a4b65211bbfa35c08e215.jpg -> train/ds1_1087_png.rf.faf77dc6bc7a4b65211bbfa35c08e215.jpg
#   Copied: 774_png.rf.9183bafd2cbb51497f2a6ad74012bc57.jpg -> train/ds1_774_png.rf.9183bafd2cbb51497f2a6ad74012bc57.jpg
#   Copied: 1103_png.rf.163246b561c8d557a84b49a7ef82697a.jpg -> train/ds1_1103_png.rf.163246b561c8d557a84b49a7ef82697a.jpg
#   Copied: 904_png.rf.34dce3012eeaaa8d4d55d64fd1a02d3a.jpg -> train/ds1_904_png.rf.34dce3012eeaaa8d4d55d64fd1a02d3a.jpg
#   Copied: 771_png.rf.dff4a7de695559770013b44c24811ceb.jpg -> train/ds1_771_png.rf.dff4a7de695559770013b44c24811ceb.jpg
#   Copied: 942_png.rf.8c95333c979178482911be606952e93c.jpg -> train/ds1_942_png.rf.8c95333c979178482911be606952e93c.jpg
#   Copied: 1135_png.rf.3a41e221bca82a85c22bdada49796f47.jpg -> train/ds1_1135_png.rf.3a41e221bca82a85c22bdada49796f47.jpg
#   Copied: 893_png.rf.c24cba17afdbc6ba9fcee89fc0f1f1b1.jpg -> train/ds1_893_png.rf.c24cba17afdbc6ba9fcee89fc0f1f1b1.jpg
#   Copied: 661_png.rf.f998459d36b0f761b8a48e6b70a0b435.jpg -> train/ds1_661_png.rf.f998459d36b0f761b8a48e6b70a0b435.jpg
#   Copied: 652_png.rf.eed4373e9da9a3461036582b7c839c70.jpg -> train/ds1_652_png.rf.eed4373e9da9a3461036582b7c839c70.jpg
#   Copied: 923_png.rf.e4f58075736da3a3c408c37d292f3f16.jpg -> train/ds1_923_png.rf.e4f58075736da3a3c408c37d292f3f16.jpg
#   Copied: 992_png.rf.f9a94a31e34815edfcc6fae3605d494f.jpg -> train/ds1_992_png.rf.f9a94a31e34815edfcc6fae3605d494f.jpg
#   Copied: 909_png.rf.9179aea6cebfaee0e98e5e02c95fc701.jpg -> train/ds1_909_png.rf.9179aea6cebfaee0e98e5e02c95fc701.jpg
#   Copied: 660_png.rf.c0eb3b3c5f8056da0a8fe43bf1c66975.jpg -> train/ds1_660_png.rf.c0eb3b3c5f8056da0a8fe43bf1c66975.jpg
#   Copied: 932_png.rf.fdb8fed12b9a93bd66241d87bc3262ff.jpg -> train/ds1_932_png.rf.fdb8fed12b9a93bd66241d87bc3262ff.jpg
#   Copied: 1102_png.rf.084156b3949b69157e09827e27a1729c.jpg -> train/ds1_1102_png.rf.084156b3949b69157e09827e27a1729c.jpg
#   Copied: 1040_png.rf.314cb02252b2b49dbf4e97a8bff7de31.jpg -> train/ds1_1040_png.rf.314cb02252b2b49dbf4e97a8bff7de31.jpg
#   Copied: 767_png.rf.ad8fd33fa60e53e96fbecae5fec51331.jpg -> train/ds1_767_png.rf.ad8fd33fa60e53e96fbecae5fec51331.jpg
#   Copied: 690_png.rf.d3f6ba59be80aff746e261ae7a2e439c.jpg -> train/ds1_690_png.rf.d3f6ba59be80aff746e261ae7a2e439c.jpg
#   Copied: 694_png.rf.eae74b44a4ca4b4174469a27e39b4a02.jpg -> train/ds1_694_png.rf.eae74b44a4ca4b4174469a27e39b4a02.jpg
#   Copied: 943_png.rf.6b06cbe55f43c16a7d72b46c139bfb6d.jpg -> train/ds1_943_png.rf.6b06cbe55f43c16a7d72b46c139bfb6d.jpg
#   Copied: 788_png.rf.7c3dd829f4aabf9aaddfa119016a7434.jpg -> train/ds1_788_png.rf.7c3dd829f4aabf9aaddfa119016a7434.jpg
#   Copied: 869_png.rf.f2afdb948ba4410cf2d00f0a909fa9ed.jpg -> train/ds1_869_png.rf.f2afdb948ba4410cf2d00f0a909fa9ed.jpg
#   Copied: 985_png.rf.996b7971f7a5c02a4fd1935d234cc5a8.jpg -> train/ds1_985_png.rf.996b7971f7a5c02a4fd1935d234cc5a8.jpg
#   Copied: 838_png.rf.ecb295002765fdd9171f052183e014fe.jpg -> train/ds1_838_png.rf.ecb295002765fdd9171f052183e014fe.jpg
#   Copied: 838_png.rf.34c4108b0479e6af6ebb3dcb38483c7b.jpg -> train/ds1_838_png.rf.34c4108b0479e6af6ebb3dcb38483c7b.jpg
#   Copied: 875_png.rf.a0fc90ca0683b8f936f4eccd2dfec337.jpg -> train/ds1_875_png.rf.a0fc90ca0683b8f936f4eccd2dfec337.jpg
#   Copied: 951_png.rf.500e97ecd42e93af50e9a3bdb6745573.jpg -> train/ds1_951_png.rf.500e97ecd42e93af50e9a3bdb6745573.jpg
#   Copied: 755_png.rf.84c3b9f024f2cd1d2d421ee46ad14c20.jpg -> train/ds1_755_png.rf.84c3b9f024f2cd1d2d421ee46ad14c20.jpg
#   Copied: 674_png.rf.febb8497437c701f5e0ff2b0074ede28.jpg -> train/ds1_674_png.rf.febb8497437c701f5e0ff2b0074ede28.jpg
#   Copied: 780_png.rf.887657f39e915b2069a5e6217a25abfd.jpg -> train/ds1_780_png.rf.887657f39e915b2069a5e6217a25abfd.jpg
#   Copied: 744_png.rf.99da8b320aaee4e9c78392a5201abb8c.jpg -> train/ds1_744_png.rf.99da8b320aaee4e9c78392a5201abb8c.jpg
#   Copied: 936_png.rf.49bb28e54e3b452b21c9bf6629fe59df.jpg -> train/ds1_936_png.rf.49bb28e54e3b452b21c9bf6629fe59df.jpg
#   Copied: 710_png.rf.073ebddc5d4c935d233d013909a8c334.jpg -> train/ds1_710_png.rf.073ebddc5d4c935d233d013909a8c334.jpg
#   Copied: 1108_png.rf.36dbe92dedaafbd1ea3f5301fd288fa4.jpg -> train/ds1_1108_png.rf.36dbe92dedaafbd1ea3f5301fd288fa4.jpg
#   Copied: 656_png.rf.78982acea1523db1e8a0d6c550b1727d.jpg -> train/ds1_656_png.rf.78982acea1523db1e8a0d6c550b1727d.jpg
#   Copied: 636_png.rf.b7fa902ce485fdaec4fc866fbc9101cc.jpg -> train/ds1_636_png.rf.b7fa902ce485fdaec4fc866fbc9101cc.jpg
#   Copied: 930_png.rf.a12818ee99d908294c3b4157e33d6edc.jpg -> train/ds1_930_png.rf.a12818ee99d908294c3b4157e33d6edc.jpg
#   Copied: 668_png.rf.32c8cf5473952cea354b6fc9007aec5b.jpg -> train/ds1_668_png.rf.32c8cf5473952cea354b6fc9007aec5b.jpg
#   Copied: 931_png.rf.dfe563ba31bb80b6cf77e897e7083191.jpg -> train/ds1_931_png.rf.dfe563ba31bb80b6cf77e897e7083191.jpg
#   Copied: 735_png.rf.51e44bbc59b2985f20387cb9614793c0.jpg -> train/ds1_735_png.rf.51e44bbc59b2985f20387cb9614793c0.jpg
#   Copied: 899_png.rf.b9e2faa8a0783b0878e4865603d63eb9.jpg -> train/ds1_899_png.rf.b9e2faa8a0783b0878e4865603d63eb9.jpg
#   Copied: 941_png.rf.bf0026cfa85c0d5bbed90fca8b2ea525.jpg -> train/ds1_941_png.rf.bf0026cfa85c0d5bbed90fca8b2ea525.jpg
#   Copied: 930_png.rf.f6a7ae36b24116eaf7c6cd1c732d5967.jpg -> train/ds1_930_png.rf.f6a7ae36b24116eaf7c6cd1c732d5967.jpg
#   Copied: 979_png.rf.15a8de0b2a7ff5c3e2553bedaad341ec.jpg -> train/ds1_979_png.rf.15a8de0b2a7ff5c3e2553bedaad341ec.jpg
#   Copied: 681_png.rf.6b7de7bc69a1c6593344f6f39fe72f03.jpg -> train/ds1_681_png.rf.6b7de7bc69a1c6593344f6f39fe72f03.jpg
#   Copied: 1054_png.rf.d0308a47a8b86654140e460b4eda320d.jpg -> train/ds1_1054_png.rf.d0308a47a8b86654140e460b4eda320d.jpg
#   Copied: 1064_png.rf.cb85b21bdd939a4ce0be8d5bdeed1b11.jpg -> train/ds1_1064_png.rf.cb85b21bdd939a4ce0be8d5bdeed1b11.jpg
#   Copied: 1112_png.rf.830005d53358f201128d09b3ff7dae09.jpg -> train/ds1_1112_png.rf.830005d53358f201128d09b3ff7dae09.jpg
#   Copied: 738_png.rf.0a1388eee597c26ad585fa707d2c5d10.jpg -> train/ds1_738_png.rf.0a1388eee597c26ad585fa707d2c5d10.jpg
#   Copied: 945_png.rf.469c96c9cf4ffba4e9958496487bbfa5.jpg -> train/ds1_945_png.rf.469c96c9cf4ffba4e9958496487bbfa5.jpg
#   Copied: 828_png.rf.259eac403aad0320b2e0c10b46168f7e.jpg -> train/ds1_828_png.rf.259eac403aad0320b2e0c10b46168f7e.jpg
#   Copied: 942_png.rf.a7b50bc3eef89ef955103a64523898d5.jpg -> train/ds1_942_png.rf.a7b50bc3eef89ef955103a64523898d5.jpg
#   Copied: 814_png.rf.bf624a465ac096837d3065b5c4f7cda8.jpg -> train/ds1_814_png.rf.bf624a465ac096837d3065b5c4f7cda8.jpg
#   Copied: 1075_png.rf.00406f5b9dd021ae709a57f6d8da149d.jpg -> train/ds1_1075_png.rf.00406f5b9dd021ae709a57f6d8da149d.jpg
#   Copied: 861_png.rf.9bb63f3aa71c7337bb79419e3ac37d50.jpg -> train/ds1_861_png.rf.9bb63f3aa71c7337bb79419e3ac37d50.jpg
#   Copied: 1117_png.rf.0b5ce250781424977bfe50fbb6b28ad6.jpg -> train/ds1_1117_png.rf.0b5ce250781424977bfe50fbb6b28ad6.jpg
#   Copied: 656_png.rf.aba533e644da6848af076a5b393ea096.jpg -> train/ds1_656_png.rf.aba533e644da6848af076a5b393ea096.jpg
#   Copied: 873_png.rf.cfffbf89d9aaf9a9dfdc12574538b8dc.jpg -> train/ds1_873_png.rf.cfffbf89d9aaf9a9dfdc12574538b8dc.jpg
#   Copied: 1077_png.rf.6edbc0f617c2fd935971c796e99d4bdb.jpg -> train/ds1_1077_png.rf.6edbc0f617c2fd935971c796e99d4bdb.jpg
#   Copied: 1053_png.rf.14590a264aa0a8004608911642dbe7bc.jpg -> train/ds1_1053_png.rf.14590a264aa0a8004608911642dbe7bc.jpg
#   Copied: 672_png.rf.ab9b97b841b7c1a2d10e528d78947211.jpg -> train/ds1_672_png.rf.ab9b97b841b7c1a2d10e528d78947211.jpg
#   Copied: 934_png.rf.d8a999f5a01ce97c97ea6c9e9c0c5a9d.jpg -> train/ds1_934_png.rf.d8a999f5a01ce97c97ea6c9e9c0c5a9d.jpg
#   Copied: 1018_png.rf.31c2bceea838fd369c46083861994de1.jpg -> train/ds1_1018_png.rf.31c2bceea838fd369c46083861994de1.jpg
#   Copied: 738_png.rf.075d964182f4e7a98c7770ca5ac0abb0.jpg -> train/ds1_738_png.rf.075d964182f4e7a98c7770ca5ac0abb0.jpg
#   Copied: 773_png.rf.42119264b950de3960119d1c1f98bceb.jpg -> train/ds1_773_png.rf.42119264b950de3960119d1c1f98bceb.jpg
#   Copied: 848_png.rf.a3c298b42caff04e8c4d6e8b82c01197.jpg -> train/ds1_848_png.rf.a3c298b42caff04e8c4d6e8b82c01197.jpg
#   Copied: 1103_png.rf.83fe582177aa499a372ab1122ddb8fce.jpg -> train/ds1_1103_png.rf.83fe582177aa499a372ab1122ddb8fce.jpg
#   Copied: 1015_png.rf.ef47401a62936fa7338def27f0cd8c3a.jpg -> train/ds1_1015_png.rf.ef47401a62936fa7338def27f0cd8c3a.jpg
#   Copied: 735_png.rf.4d76686a1bc5a517589c7eb42de3fde6.jpg -> train/ds1_735_png.rf.4d76686a1bc5a517589c7eb42de3fde6.jpg
#   Copied: 739_png.rf.8a32a29c6ad2cdd7bc42cf6cc3678467.jpg -> train/ds1_739_png.rf.8a32a29c6ad2cdd7bc42cf6cc3678467.jpg
#   Copied: 755_png.rf.cd00dc3076b07423a4bed9e0f73dc07c.jpg -> train/ds1_755_png.rf.cd00dc3076b07423a4bed9e0f73dc07c.jpg
#   Copied: 983_png.rf.38bf7a554d02fc231d764069c9f27ac3.jpg -> train/ds1_983_png.rf.38bf7a554d02fc231d764069c9f27ac3.jpg
#   Copied: 876_png.rf.db0d0f0666dfaef76a1eae40c56b1c8e.jpg -> train/ds1_876_png.rf.db0d0f0666dfaef76a1eae40c56b1c8e.jpg
#   Copied: 1030_png.rf.fe3bd5e9eb2a62a1d5edfaea222890a2.jpg -> train/ds1_1030_png.rf.fe3bd5e9eb2a62a1d5edfaea222890a2.jpg
#   Copied: 933_png.rf.e61a0d919b8d84f14d44cd6f7f5b1660.jpg -> train/ds1_933_png.rf.e61a0d919b8d84f14d44cd6f7f5b1660.jpg
#   Copied: 704_png.rf.d5938ed559d5ae6c2210d431cc704d7f.jpg -> train/ds1_704_png.rf.d5938ed559d5ae6c2210d431cc704d7f.jpg
#   Copied: 908_png.rf.e5f316649247fd8b6bb8e6730bd5a1c6.jpg -> train/ds1_908_png.rf.e5f316649247fd8b6bb8e6730bd5a1c6.jpg
#   Copied: 1098_png.rf.df477cecdd8c9828c8202ea497ff4d64.jpg -> train/ds1_1098_png.rf.df477cecdd8c9828c8202ea497ff4d64.jpg
#   Copied: 1087_png.rf.b2fc9033c5c731c3a4f51fa33ec6314a.jpg -> train/ds1_1087_png.rf.b2fc9033c5c731c3a4f51fa33ec6314a.jpg
#   Copied: 791_png.rf.a2a71f7da3be7bbfe141db6873b4987d.jpg -> train/ds1_791_png.rf.a2a71f7da3be7bbfe141db6873b4987d.jpg
#   Copied: 832_png.rf.ced22ba4ddf5a25284a26f4c97260cf4.jpg -> train/ds1_832_png.rf.ced22ba4ddf5a25284a26f4c97260cf4.jpg
#   Copied: 1087_png.rf.e1cbd1318ede8a8526244996347e867f.jpg -> train/ds1_1087_png.rf.e1cbd1318ede8a8526244996347e867f.jpg
#   Copied: 1016_png.rf.91b01187aedbe9729bd260066868ec41.jpg -> train/ds1_1016_png.rf.91b01187aedbe9729bd260066868ec41.jpg
#   Copied: 1046_png.rf.1160779cb7108eeda9c26e3288e0bfc3.jpg -> train/ds1_1046_png.rf.1160779cb7108eeda9c26e3288e0bfc3.jpg
#   Copied: 836_png.rf.0ec52786b9bb1e780f9c483f5184cd82.jpg -> train/ds1_836_png.rf.0ec52786b9bb1e780f9c483f5184cd82.jpg
#   Copied: 914_png.rf.f493cd8ef908fd8ad7d599abfaf4d941.jpg -> train/ds1_914_png.rf.f493cd8ef908fd8ad7d599abfaf4d941.jpg
#   Copied: 690_png.rf.8d7ec10ab25dac3da768155c16ab4bd8.jpg -> train/ds1_690_png.rf.8d7ec10ab25dac3da768155c16ab4bd8.jpg
#   Copied: 792_png.rf.1893e447a34ce2ec3f158e86d753ed95.jpg -> train/ds1_792_png.rf.1893e447a34ce2ec3f158e86d753ed95.jpg
#   Copied: 822_png.rf.f81745c70f454e47395f2cf9c86eb2e1.jpg -> train/ds1_822_png.rf.f81745c70f454e47395f2cf9c86eb2e1.jpg
#   Copied: 965_png.rf.28b4ba9a5f2bd710e4ac65d4f365fbc6.jpg -> train/ds1_965_png.rf.28b4ba9a5f2bd710e4ac65d4f365fbc6.jpg
#   Copied: 899_png.rf.48323ac18c7f2b6102fcebb953aaec09.jpg -> train/ds1_899_png.rf.48323ac18c7f2b6102fcebb953aaec09.jpg
#   Copied: 730_png.rf.abf8533b8f93fd9c214c097c184f49f8.jpg -> train/ds1_730_png.rf.abf8533b8f93fd9c214c097c184f49f8.jpg
#   Copied: 699_png.rf.b2ef11d6f2a485475fb676a5f4237048.jpg -> train/ds1_699_png.rf.b2ef11d6f2a485475fb676a5f4237048.jpg
#   Copied: 760_png.rf.c5b48fb017cf0d86c11e826108966c8b.jpg -> train/ds1_760_png.rf.c5b48fb017cf0d86c11e826108966c8b.jpg
#   Copied: 958_png.rf.e4a953f6368fb12f720cd732f25e8e15.jpg -> train/ds1_958_png.rf.e4a953f6368fb12f720cd732f25e8e15.jpg
#   Copied: 771_png.rf.716757ecf51a17fbdc80009ea27c040d.jpg -> train/ds1_771_png.rf.716757ecf51a17fbdc80009ea27c040d.jpg
#   Copied: 1068_png.rf.a18d3e9c16357fcd62b96efa0180edcf.jpg -> train/ds1_1068_png.rf.a18d3e9c16357fcd62b96efa0180edcf.jpg
#   Copied: 963_png.rf.0587bac98d7f6194d9110f8cb60ead48.jpg -> train/ds1_963_png.rf.0587bac98d7f6194d9110f8cb60ead48.jpg
#   Copied: 1086_png.rf.0e70958c4642a0d9d1ce14c11ca3cdc0.jpg -> train/ds1_1086_png.rf.0e70958c4642a0d9d1ce14c11ca3cdc0.jpg
#   Copied: 1016_png.rf.d9fe03c3af454036c7c13737cbb1cc95.jpg -> train/ds1_1016_png.rf.d9fe03c3af454036c7c13737cbb1cc95.jpg
#   Copied: 800_png.rf.263046f91cbefe55af1a18b23db26861.jpg -> train/ds1_800_png.rf.263046f91cbefe55af1a18b23db26861.jpg
#   Copied: 1070_png.rf.9f29cdba5a5870d22ea9ccbc85536b8b.jpg -> train/ds1_1070_png.rf.9f29cdba5a5870d22ea9ccbc85536b8b.jpg
#   Copied: 657_png.rf.8c05f646847e43442ecf115eaf7c9fb4.jpg -> train/ds1_657_png.rf.8c05f646847e43442ecf115eaf7c9fb4.jpg
#   Copied: 1037_png.rf.14d6ae61559659314db96149e1200adb.jpg -> train/ds1_1037_png.rf.14d6ae61559659314db96149e1200adb.jpg
#   Copied: 664_png.rf.ad522bfb4c2728341d23947d2abe2e01.jpg -> train/ds1_664_png.rf.ad522bfb4c2728341d23947d2abe2e01.jpg
#   Copied: 784_png.rf.aaaa740735442ceeaed5c577cad8b820.jpg -> train/ds1_784_png.rf.aaaa740735442ceeaed5c577cad8b820.jpg
#   Copied: 1001_png.rf.74a0c524befb72ca86324394d799c4ef.jpg -> train/ds1_1001_png.rf.74a0c524befb72ca86324394d799c4ef.jpg
#   Copied: 860_png.rf.3fbb214de8366b02ca860a21aa67159b.jpg -> train/ds1_860_png.rf.3fbb214de8366b02ca860a21aa67159b.jpg
#   Copied: 867_png.rf.b8ade863559749c5403f0e38d4ad6628.jpg -> train/ds1_867_png.rf.b8ade863559749c5403f0e38d4ad6628.jpg
#   Copied: 738_png.rf.a9bc9ed54c9c32f32d2ab6878768b9b9.jpg -> train/ds1_738_png.rf.a9bc9ed54c9c32f32d2ab6878768b9b9.jpg
#   Copied: 920_png.rf.4860a0ce3761c7db80629157dc91d466.jpg -> train/ds1_920_png.rf.4860a0ce3761c7db80629157dc91d466.jpg
#   Copied: 1109_png.rf.c013d7a64f724f2a75a6e61ba298c5dd.jpg -> train/ds1_1109_png.rf.c013d7a64f724f2a75a6e61ba298c5dd.jpg
#   Copied: 778_png.rf.bf70b347275dfc5855df476e36b6aba5.jpg -> train/ds1_778_png.rf.bf70b347275dfc5855df476e36b6aba5.jpg
#   Copied: 918_png.rf.a0610941a7e3caee09b968625f39b5f3.jpg -> train/ds1_918_png.rf.a0610941a7e3caee09b968625f39b5f3.jpg
#   Copied: 767_png.rf.1c600d670a480b15e566601555b4d8dd.jpg -> train/ds1_767_png.rf.1c600d670a480b15e566601555b4d8dd.jpg
#   Copied: 1008_png.rf.b2535cbddfa4a8c2f2f056c640d36abf.jpg -> train/ds1_1008_png.rf.b2535cbddfa4a8c2f2f056c640d36abf.jpg
#   Copied: 863_png.rf.7816ff09add018fe50c9a5d3679df88c.jpg -> train/ds1_863_png.rf.7816ff09add018fe50c9a5d3679df88c.jpg
#   Copied: 679_png.rf.c5caab85ae91223862194873d06b29f6.jpg -> train/ds1_679_png.rf.c5caab85ae91223862194873d06b29f6.jpg
#   Copied: 729_png.rf.6f1520db8b42b4b1b8864ceb85bc154c.jpg -> train/ds1_729_png.rf.6f1520db8b42b4b1b8864ceb85bc154c.jpg
#   Copied: 853_png.rf.776961f6f3bcf4df69a61ce2fa2a5c52.jpg -> train/ds1_853_png.rf.776961f6f3bcf4df69a61ce2fa2a5c52.jpg
#   Copied: 1078_png.rf.6149f3d5a2088e82fc1885b42962dfe8.jpg -> train/ds1_1078_png.rf.6149f3d5a2088e82fc1885b42962dfe8.jpg
#   Copied: 1108_png.rf.7576cbe411a875d6f0fe8f467e47822d.jpg -> train/ds1_1108_png.rf.7576cbe411a875d6f0fe8f467e47822d.jpg
#   Copied: 1001_png.rf.58a1baf7a4b92feb95314a36969cea13.jpg -> train/ds1_1001_png.rf.58a1baf7a4b92feb95314a36969cea13.jpg
#   Copied: 945_png.rf.e75c1b3084b808a7391fa26f80f3dbb9.jpg -> train/ds1_945_png.rf.e75c1b3084b808a7391fa26f80f3dbb9.jpg
#   Copied: 1011_png.rf.ea60bdfe2012bd2f425a62649266ecf7.jpg -> train/ds1_1011_png.rf.ea60bdfe2012bd2f425a62649266ecf7.jpg
#   Copied: 1119_png.rf.0dd3e4ebbaadb6c51f27489879989584.jpg -> train/ds1_1119_png.rf.0dd3e4ebbaadb6c51f27489879989584.jpg
#   Copied: 1038_png.rf.81418a3ff6f2464a6f27a04f6b2e03fd.jpg -> train/ds1_1038_png.rf.81418a3ff6f2464a6f27a04f6b2e03fd.jpg
#   Copied: 725_png.rf.1e365fe63d30ee07b602dd3414a3470a.jpg -> train/ds1_725_png.rf.1e365fe63d30ee07b602dd3414a3470a.jpg
#   Copied: 724_png.rf.f7db1753fcfb8295b9016e4e28d0d419.jpg -> train/ds1_724_png.rf.f7db1753fcfb8295b9016e4e28d0d419.jpg
#   Copied: 672_png.rf.f04b764b3c8409802bf906c45a1d4d90.jpg -> train/ds1_672_png.rf.f04b764b3c8409802bf906c45a1d4d90.jpg
#   Copied: 1109_png.rf.bc291e47df57d52f78514684340ab7c7.jpg -> train/ds1_1109_png.rf.bc291e47df57d52f78514684340ab7c7.jpg
#   Copied: 982_png.rf.15b3d58d02860e6bb6cc77f2837d83a2.jpg -> train/ds1_982_png.rf.15b3d58d02860e6bb6cc77f2837d83a2.jpg
#   Copied: 750_png.rf.1c22be687e38a16fa94388f2df0cfa52.jpg -> train/ds1_750_png.rf.1c22be687e38a16fa94388f2df0cfa52.jpg
#   Copied: 804_png.rf.33eeecf0ff03ee9445ded76c1a49064c.jpg -> train/ds1_804_png.rf.33eeecf0ff03ee9445ded76c1a49064c.jpg
#   Copied: 948_png.rf.54b1d1cce5072cf52d04e1b2f386cab3.jpg -> train/ds1_948_png.rf.54b1d1cce5072cf52d04e1b2f386cab3.jpg
#   Copied: 711_png.rf.a9208818d1675bc1e5c7970864ee386f.jpg -> train/ds1_711_png.rf.a9208818d1675bc1e5c7970864ee386f.jpg
#   Copied: 985_png.rf.b64456fd1868cf65dfdb9a51a4ce0850.jpg -> train/ds1_985_png.rf.b64456fd1868cf65dfdb9a51a4ce0850.jpg
#   Copied: 1127_png.rf.2d94444808d3b4cd5c2433a844fb887d.jpg -> train/ds1_1127_png.rf.2d94444808d3b4cd5c2433a844fb887d.jpg
#   Copied: 958_png.rf.476388dd6da3d4d410bcda364cee2e50.jpg -> train/ds1_958_png.rf.476388dd6da3d4d410bcda364cee2e50.jpg
#   Copied: 864_png.rf.9be7d1ffec3ba6f594ac7f2476f13a38.jpg -> train/ds1_864_png.rf.9be7d1ffec3ba6f594ac7f2476f13a38.jpg
#   Copied: 653_png.rf.fb70ea2b83321432dbafd0b20827768d.jpg -> train/ds1_653_png.rf.fb70ea2b83321432dbafd0b20827768d.jpg
#   Copied: 976_png.rf.dc1c119b2b97127e83606e13ac8d1167.jpg -> train/ds1_976_png.rf.dc1c119b2b97127e83606e13ac8d1167.jpg
#   Copied: 708_png.rf.33499e2dd9c3273a2b3e58110fe3e0bd.jpg -> train/ds1_708_png.rf.33499e2dd9c3273a2b3e58110fe3e0bd.jpg
#   Copied: 993_png.rf.7bdb1eae43322bbbec04e520f5de9ac6.jpg -> train/ds1_993_png.rf.7bdb1eae43322bbbec04e520f5de9ac6.jpg
#   Copied: 1128_png.rf.57a0aa9f99c70b8712d245c9fe66d5df.jpg -> train/ds1_1128_png.rf.57a0aa9f99c70b8712d245c9fe66d5df.jpg
#   Copied: 861_png.rf.fb76097610075849862c4839d2085ade.jpg -> train/ds1_861_png.rf.fb76097610075849862c4839d2085ade.jpg
#   Copied: 913_png.rf.2f3f95382ed5c337aedab2621dc8a99f.jpg -> train/ds1_913_png.rf.2f3f95382ed5c337aedab2621dc8a99f.jpg
#   Copied: 802_png.rf.8b85883c808dfdd421d8fcb79dea45c6.jpg -> train/ds1_802_png.rf.8b85883c808dfdd421d8fcb79dea45c6.jpg
#   Copied: 939_png.rf.6ac6b2abf9dea90681484c87c1b4cbe1.jpg -> train/ds1_939_png.rf.6ac6b2abf9dea90681484c87c1b4cbe1.jpg
#   Copied: 1113_png.rf.902411fb782fb06ffcda7525146726f8.jpg -> train/ds1_1113_png.rf.902411fb782fb06ffcda7525146726f8.jpg
#   Copied: 1006_png.rf.7b3e728f6f42337bd3549cc720d76a15.jpg -> train/ds1_1006_png.rf.7b3e728f6f42337bd3549cc720d76a15.jpg
#   Copied: 797_png.rf.aa0d2f527e6d27fdd8a342f96b99e95f.jpg -> train/ds1_797_png.rf.aa0d2f527e6d27fdd8a342f96b99e95f.jpg
#   Copied: 1129_png.rf.e9830893a126d8be76d7733c4719e18d.jpg -> train/ds1_1129_png.rf.e9830893a126d8be76d7733c4719e18d.jpg
#   Copied: 1051_png.rf.556305c048886c236f2fb4aa162cf9c1.jpg -> train/ds1_1051_png.rf.556305c048886c236f2fb4aa162cf9c1.jpg
#   Copied: 855_png.rf.219d2e9878bf464f211026ba4f8acc9b.jpg -> train/ds1_855_png.rf.219d2e9878bf464f211026ba4f8acc9b.jpg
#   Copied: 1098_png.rf.d89143444cca83581fbace5e9714add2.jpg -> train/ds1_1098_png.rf.d89143444cca83581fbace5e9714add2.jpg
#   Copied: 998_png.rf.3dbcf51a940b030566e60c559ede2a6e.jpg -> train/ds1_998_png.rf.3dbcf51a940b030566e60c559ede2a6e.jpg
#   Copied: 763_png.rf.b8e00ca1702f2c574eb91a988b897263.jpg -> train/ds1_763_png.rf.b8e00ca1702f2c574eb91a988b897263.jpg
#   Copied: 666_png.rf.7059ccbe855e194cad605a7387f54fbe.jpg -> train/ds1_666_png.rf.7059ccbe855e194cad605a7387f54fbe.jpg
#   Copied: 748_png.rf.1be4f9c4a1b02602ca173d14c20edf8f.jpg -> train/ds1_748_png.rf.1be4f9c4a1b02602ca173d14c20edf8f.jpg
#   Copied: 689_png.rf.e5e08699de1337e7183fe6aed9ac14d9.jpg -> train/ds1_689_png.rf.e5e08699de1337e7183fe6aed9ac14d9.jpg
#   Copied: 649_png.rf.ddc395f6706c28353aa06c56171f43da.jpg -> train/ds1_649_png.rf.ddc395f6706c28353aa06c56171f43da.jpg
#   Copied: 636_png.rf.6f7fa9d0b5c84af22519e91ff000aa88.jpg -> train/ds1_636_png.rf.6f7fa9d0b5c84af22519e91ff000aa88.jpg
#   Copied: 683_png.rf.db0315f6b1086975b8794b2212eef1e6.jpg -> train/ds1_683_png.rf.db0315f6b1086975b8794b2212eef1e6.jpg
#   Copied: 649_png.rf.8fdcf5ae6c0cb34cabeecd4cc2227082.jpg -> train/ds1_649_png.rf.8fdcf5ae6c0cb34cabeecd4cc2227082.jpg
#   Copied: 746_png.rf.ea1c7bf4f60f40987aca5dffae199a36.jpg -> train/ds1_746_png.rf.ea1c7bf4f60f40987aca5dffae199a36.jpg
#   Copied: 798_png.rf.a1121f1a9dbd5eaf523a3a4b9326b122.jpg -> train/ds1_798_png.rf.a1121f1a9dbd5eaf523a3a4b9326b122.jpg
#   Copied: 986_png.rf.0c8d25b22ed3b44398bc570aff91e86b.jpg -> train/ds1_986_png.rf.0c8d25b22ed3b44398bc570aff91e86b.jpg
#   Copied: 807_png.rf.6b40ad94b68b831bbbc24092ea30b0fb.jpg -> train/ds1_807_png.rf.6b40ad94b68b831bbbc24092ea30b0fb.jpg
#   Copied: 1104_png.rf.7aa5e74c72654e42e34c8e9d2d4dc2a0.jpg -> train/ds1_1104_png.rf.7aa5e74c72654e42e34c8e9d2d4dc2a0.jpg
#   Copied: 817_png.rf.954139ad92a44df46e8f507a0698dd4b.jpg -> train/ds1_817_png.rf.954139ad92a44df46e8f507a0698dd4b.jpg
#   Copied: 851_png.rf.ec35563ddd3151efeb64468d9e14a6cc.jpg -> train/ds1_851_png.rf.ec35563ddd3151efeb64468d9e14a6cc.jpg
#   Copied: 747_png.rf.b3be34ba2af59fe6f1b272e3e6355064.jpg -> train/ds1_747_png.rf.b3be34ba2af59fe6f1b272e3e6355064.jpg
#   Copied: 1004_png.rf.d271597b4324db8933a2ff0062970121.jpg -> train/ds1_1004_png.rf.d271597b4324db8933a2ff0062970121.jpg
#   Copied: 1112_png.rf.2e5bee821ae8e59040afc1204693cacf.jpg -> train/ds1_1112_png.rf.2e5bee821ae8e59040afc1204693cacf.jpg
#   Copied: 731_png.rf.1aa5444f17aa799c1c546fac3964648b.jpg -> train/ds1_731_png.rf.1aa5444f17aa799c1c546fac3964648b.jpg
#   Copied: 799_png.rf.5c36b64c9e53b885ec8510d2960ed116.jpg -> train/ds1_799_png.rf.5c36b64c9e53b885ec8510d2960ed116.jpg
#   Copied: 1018_png.rf.39f697d8848cc52660ba2067184de94c.jpg -> train/ds1_1018_png.rf.39f697d8848cc52660ba2067184de94c.jpg
#   Copied: 657_png.rf.3d4679a597b69458309a8467ce2bee7b.jpg -> train/ds1_657_png.rf.3d4679a597b69458309a8467ce2bee7b.jpg
#   Copied: 990_png.rf.1bab063e8e3ec79e55748cc5361d2aa0.jpg -> train/ds1_990_png.rf.1bab063e8e3ec79e55748cc5361d2aa0.jpg
#   Copied: 647_png.rf.965fd17f2e772211eedb585413e9805b.jpg -> train/ds1_647_png.rf.965fd17f2e772211eedb585413e9805b.jpg
#   Copied: 897_png.rf.84b28eb927c898961f027ba04610065f.jpg -> train/ds1_897_png.rf.84b28eb927c898961f027ba04610065f.jpg
#   Copied: 954_png.rf.f045fd5b5c7238bd41d49cca40634f01.jpg -> train/ds1_954_png.rf.f045fd5b5c7238bd41d49cca40634f01.jpg
#   Copied: 890_png.rf.00882e44286d734d908b51ffa08de5e0.jpg -> train/ds1_890_png.rf.00882e44286d734d908b51ffa08de5e0.jpg
#   Copied: 916_png.rf.d589f3c1d2a6daf26b0d3e55d5f57bda.jpg -> train/ds1_916_png.rf.d589f3c1d2a6daf26b0d3e55d5f57bda.jpg
#   Copied: 987_png.rf.8adb7648be49a5476b2f9b0cecaa27fd.jpg -> train/ds1_987_png.rf.8adb7648be49a5476b2f9b0cecaa27fd.jpg
#   Copied: 1046_png.rf.10558588f4fd44ffd697a120f5435975.jpg -> train/ds1_1046_png.rf.10558588f4fd44ffd697a120f5435975.jpg
#   Copied: 695_png.rf.abf6b044d2e831899ee4d66178f86e91.jpg -> train/ds1_695_png.rf.abf6b044d2e831899ee4d66178f86e91.jpg
#   Copied: 1009_png.rf.db056ab1730e3d3766ec35197828e7b6.jpg -> train/ds1_1009_png.rf.db056ab1730e3d3766ec35197828e7b6.jpg
#   Copied: 807_png.rf.7a1cdd6c30a80a3818b0f97171dd3e17.jpg -> train/ds1_807_png.rf.7a1cdd6c30a80a3818b0f97171dd3e17.jpg
#   Copied: 944_png.rf.752042f43926af7c919fb710884f7afb.jpg -> train/ds1_944_png.rf.752042f43926af7c919fb710884f7afb.jpg
#   Copied: 1024_png.rf.cfe7748c51f93713877bdd89ae9f1913.jpg -> train/ds1_1024_png.rf.cfe7748c51f93713877bdd89ae9f1913.jpg
#   Copied: 719_png.rf.62bb61b65e577cf6b2363d6cd3df02f0.jpg -> train/ds1_719_png.rf.62bb61b65e577cf6b2363d6cd3df02f0.jpg
#   Copied: 1052_png.rf.79021123ff25704b9cd8b028882faea0.jpg -> train/ds1_1052_png.rf.79021123ff25704b9cd8b028882faea0.jpg
#   Copied: 804_png.rf.ee4e4758dd74c360d799087cafd4f1cd.jpg -> train/ds1_804_png.rf.ee4e4758dd74c360d799087cafd4f1cd.jpg
#   Copied: 1078_png.rf.85dd8aa0bacd66b74f05dde6ef1d1f6a.jpg -> train/ds1_1078_png.rf.85dd8aa0bacd66b74f05dde6ef1d1f6a.jpg
#   Copied: 1012_png.rf.94b1b40f8d6d09a7131d39cc7a765fe1.jpg -> train/ds1_1012_png.rf.94b1b40f8d6d09a7131d39cc7a765fe1.jpg
#   Copied: 725_png.rf.97b6af8126e1777616a3dee6f1e6d638.jpg -> train/ds1_725_png.rf.97b6af8126e1777616a3dee6f1e6d638.jpg
#   Copied: 1024_png.rf.201456a31ee1c52c816e8a317982523b.jpg -> train/ds1_1024_png.rf.201456a31ee1c52c816e8a317982523b.jpg
#   Copied: 921_png.rf.035bd0dcd680f606c7f490fbe943abe5.jpg -> train/ds1_921_png.rf.035bd0dcd680f606c7f490fbe943abe5.jpg
#   Copied: 1078_png.rf.e3f3236abfc0eaacbb0c0a49791ffbb1.jpg -> train/ds1_1078_png.rf.e3f3236abfc0eaacbb0c0a49791ffbb1.jpg
#   Copied: 859_png.rf.bbfbfb5f3649116cbbeea74056bd7e19.jpg -> train/ds1_859_png.rf.bbfbfb5f3649116cbbeea74056bd7e19.jpg
#   Copied: 979_png.rf.8503b6124af07ae6d28be5142773edcd.jpg -> train/ds1_979_png.rf.8503b6124af07ae6d28be5142773edcd.jpg
#   Copied: 926_png.rf.9e2498cb0ad65db765445acd9a37404d.jpg -> train/ds1_926_png.rf.9e2498cb0ad65db765445acd9a37404d.jpg
#   Copied: 1084_png.rf.d893cf56cba6592532262cc918770218.jpg -> train/ds1_1084_png.rf.d893cf56cba6592532262cc918770218.jpg
#   Copied: 1072_png.rf.19909e7f28b96f2967cf29f9d76925db.jpg -> train/ds1_1072_png.rf.19909e7f28b96f2967cf29f9d76925db.jpg
#   Copied: 1076_png.rf.37023cea4d840d727eb264e8fd9d2982.jpg -> train/ds1_1076_png.rf.37023cea4d840d727eb264e8fd9d2982.jpg
#   Copied: 928_png.rf.994b6654868a5ea6aa65d35d7961b2d5.jpg -> train/ds1_928_png.rf.994b6654868a5ea6aa65d35d7961b2d5.jpg
#   Copied: 676_png.rf.9d5dc25b6f15848fb21036a9da3a27cf.jpg -> train/ds1_676_png.rf.9d5dc25b6f15848fb21036a9da3a27cf.jpg
#   Copied: 917_png.rf.047c57238abf20c5bcb4d6229e39af69.jpg -> train/ds1_917_png.rf.047c57238abf20c5bcb4d6229e39af69.jpg
#   Copied: 1126_png.rf.1b182cba2a6c9e80c94ff3a4d5653990.jpg -> train/ds1_1126_png.rf.1b182cba2a6c9e80c94ff3a4d5653990.jpg
#   Copied: 726_png.rf.ed6ac52de8a58d79aea963077d8b62a6.jpg -> train/ds1_726_png.rf.ed6ac52de8a58d79aea963077d8b62a6.jpg
#   Copied: 842_png.rf.074fe6a444791b75b1df5f011cd4827b.jpg -> train/ds1_842_png.rf.074fe6a444791b75b1df5f011cd4827b.jpg
#   Copied: 639_png.rf.0defa887837a49165738f870afb7d156.jpg -> train/ds1_639_png.rf.0defa887837a49165738f870afb7d156.jpg
#   Copied: 662_png.rf.a1b460b81cd3329ba27ebd907c618f78.jpg -> train/ds1_662_png.rf.a1b460b81cd3329ba27ebd907c618f78.jpg
#   Copied: 716_png.rf.fb7936899a2cae1fe0c119a66159fa20.jpg -> train/ds1_716_png.rf.fb7936899a2cae1fe0c119a66159fa20.jpg
#   Copied: 1095_png.rf.8d19b6c17c6adc83f871a38c1a080e43.jpg -> train/ds1_1095_png.rf.8d19b6c17c6adc83f871a38c1a080e43.jpg
#   Copied: 659_png.rf.1daae228ad6de84a21925da57404f257.jpg -> train/ds1_659_png.rf.1daae228ad6de84a21925da57404f257.jpg
#   Copied: 652_png.rf.9cb6eb47e9e80a3d3d822599df9f1340.jpg -> train/ds1_652_png.rf.9cb6eb47e9e80a3d3d822599df9f1340.jpg
#   Copied: 948_png.rf.8ca5f357619e8c620be81c00154ddd0c.jpg -> train/ds1_948_png.rf.8ca5f357619e8c620be81c00154ddd0c.jpg
#   Copied: 716_png.rf.bdfac3d27bd46bdee5858c5482342dea.jpg -> train/ds1_716_png.rf.bdfac3d27bd46bdee5858c5482342dea.jpg
#   Copied: 1040_png.rf.ee4b5214665b67dace12b5c3c32cf96d.jpg -> train/ds1_1040_png.rf.ee4b5214665b67dace12b5c3c32cf96d.jpg
#   Copied: 698_png.rf.cc9f3592f8101add93642d90583d095a.jpg -> train/ds1_698_png.rf.cc9f3592f8101add93642d90583d095a.jpg
#   Copied: 868_png.rf.7de19d6aafe58fcca38480258f1134a2.jpg -> train/ds1_868_png.rf.7de19d6aafe58fcca38480258f1134a2.jpg
#   Copied: 1032_png.rf.179e80f6620aef8dfa24d6a53f18e8da.jpg -> train/ds1_1032_png.rf.179e80f6620aef8dfa24d6a53f18e8da.jpg
#   Copied: 896_png.rf.a5a96e03339036e71dc4558a3f79bbc8.jpg -> train/ds1_896_png.rf.a5a96e03339036e71dc4558a3f79bbc8.jpg
#   Copied: 999_png.rf.ee10fca595ff9b570eefc0be4900415c.jpg -> train/ds1_999_png.rf.ee10fca595ff9b570eefc0be4900415c.jpg
#   Copied: 1129_png.rf.77dc0453b04fd17098dcdd1ee31895a4.jpg -> train/ds1_1129_png.rf.77dc0453b04fd17098dcdd1ee31895a4.jpg
#   Copied: 642_png.rf.86dac4b9794a44bfd1a986aa3d919eec.jpg -> train/ds1_642_png.rf.86dac4b9794a44bfd1a986aa3d919eec.jpg
#   Copied: 1054_png.rf.2a7f2366ee39fca34f4e6270a0c57f84.jpg -> train/ds1_1054_png.rf.2a7f2366ee39fca34f4e6270a0c57f84.jpg
#   Copied: 992_png.rf.d8fa507f5f550caf55c12e70b82640d4.jpg -> train/ds1_992_png.rf.d8fa507f5f550caf55c12e70b82640d4.jpg
#   Copied: 1073_png.rf.f0c06d3601c6e1856c2cab62871f3715.jpg -> train/ds1_1073_png.rf.f0c06d3601c6e1856c2cab62871f3715.jpg
#   Copied: 1033_png.rf.4f901e73bdb1ec9f4965353c52fb5376.jpg -> train/ds1_1033_png.rf.4f901e73bdb1ec9f4965353c52fb5376.jpg
#   Copied: 877_png.rf.f97044f4899fe0564581f3e0268a741a.jpg -> train/ds1_877_png.rf.f97044f4899fe0564581f3e0268a741a.jpg
#   Copied: 1116_png.rf.1b192683036a98e0a3328ad9cc5d885a.jpg -> train/ds1_1116_png.rf.1b192683036a98e0a3328ad9cc5d885a.jpg
#   Copied: 724_png.rf.86ea559c09b7670688dd479d5193757b.jpg -> train/ds1_724_png.rf.86ea559c09b7670688dd479d5193757b.jpg
#   Copied: 1013_png.rf.2fb7658b857e0326e0c7c840aedeade5.jpg -> train/ds1_1013_png.rf.2fb7658b857e0326e0c7c840aedeade5.jpg
#   Copied: 1071_png.rf.7104a044cd471b650d786321516fb884.jpg -> train/ds1_1071_png.rf.7104a044cd471b650d786321516fb884.jpg
#   Copied: 770_png.rf.1473fe79e5ac9b1e3b08352c5db89f51.jpg -> train/ds1_770_png.rf.1473fe79e5ac9b1e3b08352c5db89f51.jpg
#   Copied: 930_png.rf.3863178a1ddc33f0f5db9d77761b2ceb.jpg -> train/ds1_930_png.rf.3863178a1ddc33f0f5db9d77761b2ceb.jpg
#   Copied: 938_png.rf.b25cda63412e5a1ee25006ad6d846716.jpg -> train/ds1_938_png.rf.b25cda63412e5a1ee25006ad6d846716.jpg
#   Copied: 733_png.rf.e09b10d74a97dd92747128eb588778cb.jpg -> train/ds1_733_png.rf.e09b10d74a97dd92747128eb588778cb.jpg
#   Copied: 908_png.rf.8070a369134d71f20ea19caedd11576d.jpg -> train/ds1_908_png.rf.8070a369134d71f20ea19caedd11576d.jpg
#   Copied: 655_png.rf.2e5a12ad63aa4c811cc7820f7ff8eaea.jpg -> train/ds1_655_png.rf.2e5a12ad63aa4c811cc7820f7ff8eaea.jpg
#   Copied: 1074_png.rf.3026489ad778f2a0b8068497b21b6e83.jpg -> train/ds1_1074_png.rf.3026489ad778f2a0b8068497b21b6e83.jpg
#   Copied: 1117_png.rf.e0198c9aed1beb2b05651f30fbef7a9f.jpg -> train/ds1_1117_png.rf.e0198c9aed1beb2b05651f30fbef7a9f.jpg
#   Copied: 940_png.rf.e9ae2588ac3f3a9f1c22e9fc32b83188.jpg -> train/ds1_940_png.rf.e9ae2588ac3f3a9f1c22e9fc32b83188.jpg
#   Copied: 1023_png.rf.b2213578e61e01de89b9eb16d6727c36.jpg -> train/ds1_1023_png.rf.b2213578e61e01de89b9eb16d6727c36.jpg
#   Copied: 662_png.rf.132e56be39ff3015cf3966799b2af21c.jpg -> train/ds1_662_png.rf.132e56be39ff3015cf3966799b2af21c.jpg
#   Copied: 979_png.rf.2ba19955d0844f9b73bcb03c9ce221a8.jpg -> train/ds1_979_png.rf.2ba19955d0844f9b73bcb03c9ce221a8.jpg
#   Copied: 1071_png.rf.8c1b7f41a50b217ed316f954544fe9ed.jpg -> train/ds1_1071_png.rf.8c1b7f41a50b217ed316f954544fe9ed.jpg
#   Copied: 1014_png.rf.b3a9ff7c01c0c925c6607d828f123d36.jpg -> train/ds1_1014_png.rf.b3a9ff7c01c0c925c6607d828f123d36.jpg
#   Copied: 777_png.rf.7258ff64d50794870f59c5cb3616d893.jpg -> train/ds1_777_png.rf.7258ff64d50794870f59c5cb3616d893.jpg
#   Copied: 842_png.rf.d10a037ed99394c45635f3db5526d601.jpg -> train/ds1_842_png.rf.d10a037ed99394c45635f3db5526d601.jpg
#   Copied: 1059_png.rf.f2888bd80053984feedf38aa7ce116e2.jpg -> train/ds1_1059_png.rf.f2888bd80053984feedf38aa7ce116e2.jpg
#   Copied: 1067_png.rf.34de374ac7503872277d20e5fd505dc6.jpg -> train/ds1_1067_png.rf.34de374ac7503872277d20e5fd505dc6.jpg
#   Copied: 735_png.rf.51a3358b6593884384e3f29eb5481f0d.jpg -> train/ds1_735_png.rf.51a3358b6593884384e3f29eb5481f0d.jpg
#   Copied: 758_png.rf.471112e68d7f3c1870e9ed38c2609347.jpg -> train/ds1_758_png.rf.471112e68d7f3c1870e9ed38c2609347.jpg
#   Copied: 1070_png.rf.07ebb3197962fc69f60a8328bb8c8a56.jpg -> train/ds1_1070_png.rf.07ebb3197962fc69f60a8328bb8c8a56.jpg
#   Copied: 1029_png.rf.7e75e6d5922aebde6eef6702ef7303bc.jpg -> train/ds1_1029_png.rf.7e75e6d5922aebde6eef6702ef7303bc.jpg
#   Copied: 1098_png.rf.1b6ecbb47f75f2a144b55501781713cf.jpg -> train/ds1_1098_png.rf.1b6ecbb47f75f2a144b55501781713cf.jpg
#   Copied: 664_png.rf.bd009d20a21671e336d69e4f36b1623e.jpg -> train/ds1_664_png.rf.bd009d20a21671e336d69e4f36b1623e.jpg
#   Copied: 672_png.rf.5c5418aa27940262c892febe6fab89f9.jpg -> train/ds1_672_png.rf.5c5418aa27940262c892febe6fab89f9.jpg
#   Copied: 855_png.rf.5785836f2fb7e402628c958c3e40084f.jpg -> train/ds1_855_png.rf.5785836f2fb7e402628c958c3e40084f.jpg
#   Copied: 641_png.rf.d5ccb822a67c47db62f1318d0804b02a.jpg -> train/ds1_641_png.rf.d5ccb822a67c47db62f1318d0804b02a.jpg
#   Copied: 1086_png.rf.79c6ece6d7837ddab4e113c2916f769d.jpg -> train/ds1_1086_png.rf.79c6ece6d7837ddab4e113c2916f769d.jpg
#   Copied: 1028_png.rf.c06796055e3e6b84b4ff87064a22caf3.jpg -> train/ds1_1028_png.rf.c06796055e3e6b84b4ff87064a22caf3.jpg
#   Copied: 777_png.rf.705e8dcccb90fceb26f6112c4d911c39.jpg -> train/ds1_777_png.rf.705e8dcccb90fceb26f6112c4d911c39.jpg
#   Copied: 1051_png.rf.c57d6803f3eb9d6bc22fee23c0f137c7.jpg -> train/ds1_1051_png.rf.c57d6803f3eb9d6bc22fee23c0f137c7.jpg
#   Copied: 708_png.rf.75ee13fbec076dec10436bb9ddec0b9b.jpg -> train/ds1_708_png.rf.75ee13fbec076dec10436bb9ddec0b9b.jpg
#   Copied: 827_png.rf.ea35214fb3eaadca57a31fad286b8c14.jpg -> train/ds1_827_png.rf.ea35214fb3eaadca57a31fad286b8c14.jpg
#   Copied: 751_png.rf.a1fb914e19706e3d5f66c66182b20889.jpg -> train/ds1_751_png.rf.a1fb914e19706e3d5f66c66182b20889.jpg
#   Copied: 829_png.rf.0c926560e1822ccca558f22355770d63.jpg -> train/ds1_829_png.rf.0c926560e1822ccca558f22355770d63.jpg
#   Copied: 687_png.rf.324751a97cc15a02ccad651fcf5dafa3.jpg -> train/ds1_687_png.rf.324751a97cc15a02ccad651fcf5dafa3.jpg
#   Copied: 721_png.rf.132bf56db4958962ac9e022f1da4b3a9.jpg -> train/ds1_721_png.rf.132bf56db4958962ac9e022f1da4b3a9.jpg
#   Copied: 1125_png.rf.5fc9f95fe77ac45438272a0a8be9950a.jpg -> train/ds1_1125_png.rf.5fc9f95fe77ac45438272a0a8be9950a.jpg
#   Copied: 892_png.rf.2dd0ae2bec2834705fa2da38e5e4c41c.jpg -> train/ds1_892_png.rf.2dd0ae2bec2834705fa2da38e5e4c41c.jpg
# ...
#   Copied: 946_png.rf.fc86936df1f08b6ba2b6c1f2f02cdc95.jpg -> val/ds1_946_png.rf.fc86936df1f08b6ba2b6c1f2f02cdc95.jpg
#   Copied: 643_png.rf.cf76b39fc5d215c433d9442ca9cf13f0.jpg -> val/ds1_643_png.rf.cf76b39fc5d215c433d9442ca9cf13f0.jpg
#   Copied: 818_png.rf.aa0affa85edd8843cb7df5f129f9e4dc.jpg -> val/ds1_818_png.rf.aa0affa85edd8843cb7df5f129f9e4dc.jpg
#   Copied: 984_png.rf.ccc30920f4bbc0e4e25f580139efbb30.jpg -> val/ds1_984_png.rf.ccc30920f4bbc0e4e25f580139efbb30.jpg
#   Copied: 946_png.rf.118c5e6e883d2833e9d69644fa3626df.jpg -> val/ds1_946_png.rf.118c5e6e883d2833e9d69644fa3626df.jpg
#   Copied: 637_png.rf.177a65c6d864dd3c05966830fa0b417a.jpg -> val/ds1_637_png.rf.177a65c6d864dd3c05966830fa0b417a.jpg
#   Copied: 1082_png.rf.9a0b180cea350468714e2c770c18e107.jpg -> val/ds1_1082_png.rf.9a0b180cea350468714e2c770c18e107.jpg
#   Copied: 644_png.rf.a1f6fecab5912ead1507298445413304.jpg -> val/ds1_644_png.rf.a1f6fecab5912ead1507298445413304.jpg
#   Copied: 1086_png.rf.aed84fc466cb519b1f3d037bb973d5e1.jpg -> val/ds1_1086_png.rf.aed84fc466cb519b1f3d037bb973d5e1.jpg
#   Copied: 762_png.rf.5536831f841154c1bae843864be96e3a.jpg -> val/ds1_762_png.rf.5536831f841154c1bae843864be96e3a.jpg
#   Copied: 891_png.rf.f0c1ea7e889d8606c013bf64c7064284.jpg -> val/ds1_891_png.rf.f0c1ea7e889d8606c013bf64c7064284.jpg
#   Copied: 727_png.rf.245a96574ccf9a827fced5be04594242.jpg -> val/ds1_727_png.rf.245a96574ccf9a827fced5be04594242.jpg
#   Copied: 786_png.rf.24a308e5b14406ed66754c759ffd9f59.jpg -> val/ds1_786_png.rf.24a308e5b14406ed66754c759ffd9f59.jpg
#   Copied: 897_png.rf.c12640d7035b230f39e5f9df1e5c60d3.jpg -> val/ds1_897_png.rf.c12640d7035b230f39e5f9df1e5c60d3.jpg
#   Copied: 1120_png.rf.940fceba9624aec38597859de8c6a7e3.jpg -> val/ds1_1120_png.rf.940fceba9624aec38597859de8c6a7e3.jpg
#   Copied: 670_png.rf.9182fd6db0af96fedb2898ba6382ec70.jpg -> val/ds1_670_png.rf.9182fd6db0af96fedb2898ba6382ec70.jpg
#   Copied: 933_png.rf.c003290fb75d5932ef7d4d6724e844a3.jpg -> val/ds1_933_png.rf.c003290fb75d5932ef7d4d6724e844a3.jpg
#   Copied: 838_png.rf.84fa68ad3e64597f1d517d135d46e44d.jpg -> val/ds1_838_png.rf.84fa68ad3e64597f1d517d135d46e44d.jpg
#   Copied: 1120_png.rf.120ada64180b6ca172a9c5aa472cb597.jpg -> val/ds1_1120_png.rf.120ada64180b6ca172a9c5aa472cb597.jpg
#   Copied: 1040_png.rf.5ae275619d15b9ce7dfc5983b63f53f4.jpg -> val/ds1_1040_png.rf.5ae275619d15b9ce7dfc5983b63f53f4.jpg
#   Copied: 646_png.rf.5abbe4b5f66fe96b306f01cf7104ec3d.jpg -> val/ds1_646_png.rf.5abbe4b5f66fe96b306f01cf7104ec3d.jpg
#   Copied: 729_png.rf.927e9763c5eaeebeaed5e66102054cf5.jpg -> val/ds1_729_png.rf.927e9763c5eaeebeaed5e66102054cf5.jpg
#   Copied: 670_png.rf.b9bf04961338b27494376e22212d6e57.jpg -> val/ds1_670_png.rf.b9bf04961338b27494376e22212d6e57.jpg
#   Copied: 993_png.rf.92eb94670a979f141a84f11c69dc97e1.jpg -> val/ds1_993_png.rf.92eb94670a979f141a84f11c69dc97e1.jpg
#   Copied: 1018_png.rf.4634e7dc52af58053da2929196650328.jpg -> val/ds1_1018_png.rf.4634e7dc52af58053da2929196650328.jpg
#   Copied: 1027_png.rf.28ba5fd2dec5fe48376c5780a1c09988.jpg -> val/ds1_1027_png.rf.28ba5fd2dec5fe48376c5780a1c09988.jpg
#   Copied: 1128_png.rf.07fa111163f5dae3c05edef7061e4738.jpg -> val/ds1_1128_png.rf.07fa111163f5dae3c05edef7061e4738.jpg
#   Copied: 1035_png.rf.71857a6e7bc5e064de403a45021e8ec6.jpg -> val/ds1_1035_png.rf.71857a6e7bc5e064de403a45021e8ec6.jpg
#   Copied: 965_png.rf.895a02221f0d9d4d18e2683ad786b134.jpg -> val/ds1_965_png.rf.895a02221f0d9d4d18e2683ad786b134.jpg
#   Copied: 960_png.rf.8444da7e1178c3ca3e7928ed870d181e.jpg -> val/ds1_960_png.rf.8444da7e1178c3ca3e7928ed870d181e.jpg
#   Copied: 688_png.rf.adf40dc8a9bfb19efdd986f9ed36d55a.jpg -> val/ds1_688_png.rf.adf40dc8a9bfb19efdd986f9ed36d55a.jpg
#   Copied: page_22.png -> val/ds2_page_22.png
#   Copied: page_3.png -> val/ds2_page_3.png
#   Copied: page_30.png -> val/ds2_page_30.png
#   Copied: 680_png.rf.f276f1ed276913f23035d155b0e39cc5.jpg -> test/ds1_680_png.rf.f276f1ed276913f23035d155b0e39cc5.jpg
#   Copied: 912_png.rf.d059581875bbfae7a5d6399ad4562b2c.jpg -> test/ds1_912_png.rf.d059581875bbfae7a5d6399ad4562b2c.jpg
#   Copied: 1122_png.rf.9a69fe79a07195c0dde74b3ee06a3025.jpg -> test/ds1_1122_png.rf.9a69fe79a07195c0dde74b3ee06a3025.jpg
#   Copied: 835_png.rf.a72a7ce32cdb5ea52a6e7e04dbe62e1e.jpg -> test/ds1_835_png.rf.a72a7ce32cdb5ea52a6e7e04dbe62e1e.jpg
#   Copied: 913_png.rf.eafeaeb4067e65dc66863698ae187495.jpg -> test/ds1_913_png.rf.eafeaeb4067e65dc66863698ae187495.jpg
#   Copied: 884_png.rf.6ac1cdbad4cc9578096582575a27082c.jpg -> test/ds1_884_png.rf.6ac1cdbad4cc9578096582575a27082c.jpg
#   Copied: 647_png.rf.398310449934d329e17b1c84a8908f2e.jpg -> test/ds1_647_png.rf.398310449934d329e17b1c84a8908f2e.jpg
#   Copied: 713_png.rf.774bd235421015a6e098922ef455adb0.jpg -> test/ds1_713_png.rf.774bd235421015a6e098922ef455adb0.jpg
#   Copied: 763_png.rf.e40a497425c0766c0dec3f77b4a0a3eb.jpg -> test/ds1_763_png.rf.e40a497425c0766c0dec3f77b4a0a3eb.jpg
#   Copied: 1096_png.rf.81877c8b04feaa74c501f4f285c41f3c.jpg -> test/ds1_1096_png.rf.81877c8b04feaa74c501f4f285c41f3c.jpg
#   Copied: 636_png.rf.8da0c54b466613e8b8e03aab943275d0.jpg -> test/ds1_636_png.rf.8da0c54b466613e8b8e03aab943275d0.jpg
#   Copied: 937_png.rf.c108464e55330071ed3e79244c90018b.jpg -> test/ds1_937_png.rf.c108464e55330071ed3e79244c90018b.jpg
#   Copied: 817_png.rf.5573773ec1410124e513745696e79a74.jpg -> test/ds1_817_png.rf.5573773ec1410124e513745696e79a74.jpg
#   Copied: 1102_png.rf.a2f802387878892f21008a31c7a56b9b.jpg -> test/ds1_1102_png.rf.a2f802387878892f21008a31c7a56b9b.jpg
#   Copied: 847_png.rf.cf3726faeb479c4d2ff26db25b1816c7.jpg -> test/ds1_847_png.rf.cf3726faeb479c4d2ff26db25b1816c7.jpg
#   Copied: 863_png.rf.cb42c8f4d0a935ecd6caccb4c0334fd2.jpg -> test/ds1_863_png.rf.cb42c8f4d0a935ecd6caccb4c0334fd2.jpg
#   Copied: 1043_png.rf.42c8dd019eff629aa39aba825396b330.jpg -> test/ds1_1043_png.rf.42c8dd019eff629aa39aba825396b330.jpg
#   Copied: 894_png.rf.0c70babf731673aec3b69f3cd117377c.jpg -> test/ds1_894_png.rf.0c70babf731673aec3b69f3cd117377c.jpg
#   Copied: 912_png.rf.8b84d49c94c0e0fbc86e932d48f21624.jpg -> test/ds1_912_png.rf.8b84d49c94c0e0fbc86e932d48f21624.jpg
#   Copied: 955_png.rf.a09a5d28bd34bf151e558c0beadaa822.jpg -> test/ds1_955_png.rf.a09a5d28bd34bf151e558c0beadaa822.jpg
#   Copied: 646_png.rf.371aedc4ae4bd62e2b34a6387b103b87.jpg -> test/ds1_646_png.rf.371aedc4ae4bd62e2b34a6387b103b87.jpg
#   Copied: 906_png.rf.9d4610af140a10351fa55f3079998e33.jpg -> test/ds1_906_png.rf.9d4610af140a10351fa55f3079998e33.jpg
#   Copied: 1119_png.rf.eb2048e3ec73929fa2224dc5e83e7731.jpg -> test/ds1_1119_png.rf.eb2048e3ec73929fa2224dc5e83e7731.jpg
#   Copied: 698_png.rf.1dbad2ccc77822334b787fb325b536a4.jpg -> test/ds1_698_png.rf.1dbad2ccc77822334b787fb325b536a4.jpg
#   Copied: 709_png.rf.58f6da0bbb36db603b1d2c48fbeb2478.jpg -> test/ds1_709_png.rf.58f6da0bbb36db603b1d2c48fbeb2478.jpg
#   Copied: 1096_png.rf.7eaf7354020a9b28f7d7c5a32a22c7de.jpg -> test/ds1_1096_png.rf.7eaf7354020a9b28f7d7c5a32a22c7de.jpg
#   Copied: 704_png.rf.d940f7328eba3bf4dab6497534a6c81c.jpg -> test/ds1_704_png.rf.d940f7328eba3bf4dab6497534a6c81c.jpg
#   Copied: 1134_png.rf.15e9e1373edc5967e9b46b3bbc72e7d6.jpg -> test/ds1_1134_png.rf.15e9e1373edc5967e9b46b3bbc72e7d6.jpg
#   Copied: 879_png.rf.bbea3f69551a89c7b878d6bb4f22b804.jpg -> test/ds1_879_png.rf.bbea3f69551a89c7b878d6bb4f22b804.jpg
#   Copied: 760_png.rf.c746c7dc7ced39e05f750745fe7790b9.jpg -> test/ds1_760_png.rf.c746c7dc7ced39e05f750745fe7790b9.jpg
#   Copied: 803_png.rf.6a466bcf8214922cb02fdd0c32a2d533.jpg -> test/ds1_803_png.rf.6a466bcf8214922cb02fdd0c32a2d533.jpg
#   Copied: 696_png.rf.1d75ef89b1adfd7731f50cd22a613a18.jpg -> test/ds1_696_png.rf.1d75ef89b1adfd7731f50cd22a613a18.jpg
#   Copied: 1060_png.rf.8a0558f9aea7dd851c6fbfa889c739f4.jpg -> test/ds1_1060_png.rf.8a0558f9aea7dd851c6fbfa889c739f4.jpg
#   Copied: 812_png.rf.c575b43598f93af4b8e3aa4e7eca88e7.jpg -> test/ds1_812_png.rf.c575b43598f93af4b8e3aa4e7eca88e7.jpg
#   Copied: 1129_png.rf.dedc6234df72e07d86ca009bf22a9778.jpg -> test/ds1_1129_png.rf.dedc6234df72e07d86ca009bf22a9778.jpg
#   Copied: 765_png.rf.7028b5a8155347e6ebd68f1cd9bd547f.jpg -> test/ds1_765_png.rf.7028b5a8155347e6ebd68f1cd9bd547f.jpg
#   Copied: 1049_png.rf.47fc1b06f958ad3f0922314d9f817b0a.jpg -> test/ds1_1049_png.rf.47fc1b06f958ad3f0922314d9f817b0a.jpg
#   Copied: 655_png.rf.a647af2ce0e1084e364a0a6253f4d345.jpg -> test/ds1_655_png.rf.a647af2ce0e1084e364a0a6253f4d345.jpg
#   Copied: 963_png.rf.b2106175271b1903d492f3346415bd4a.jpg -> test/ds1_963_png.rf.b2106175271b1903d492f3346415bd4a.jpg
#   Copied: 1127_png.rf.670fbaa11f10a38be8e4d75c8800b231.jpg -> test/ds1_1127_png.rf.670fbaa11f10a38be8e4d75c8800b231.jpg
#   Copied: 901_png.rf.9557cf97038716ab51fd908bf1702c01.jpg -> test/ds1_901_png.rf.9557cf97038716ab51fd908bf1702c01.jpg
#   Copied: 1029_png.rf.3f786c6952e365979c26317652965fbb.jpg -> test/ds1_1029_png.rf.3f786c6952e365979c26317652965fbb.jpg
#   Copied: 1042_png.rf.c0cf06d4c708b77b91c912c7b8b88d55.jpg -> test/ds1_1042_png.rf.c0cf06d4c708b77b91c912c7b8b88d55.jpg
#   Copied: 923_png.rf.84e4d140fd6cd67b4e6188c1f2e69a94.jpg -> test/ds1_923_png.rf.84e4d140fd6cd67b4e6188c1f2e69a94.jpg
#   Copied: 1111_png.rf.5a82a4216afb8971189e8dad383f6cfc.jpg -> test/ds1_1111_png.rf.5a82a4216afb8971189e8dad383f6cfc.jpg
#   Copied: 846_png.rf.89474a758bacc771af1d7ea535326884.jpg -> test/ds1_846_png.rf.89474a758bacc771af1d7ea535326884.jpg
#   Copied: 703_png.rf.b71adcf1a86443a8fe864b11a103f291.jpg -> test/ds1_703_png.rf.b71adcf1a86443a8fe864b11a103f291.jpg
#   Copied: 787_png.rf.b597b2706e399282aecc6f524921f22d.jpg -> test/ds1_787_png.rf.b597b2706e399282aecc6f524921f22d.jpg
#   Copied: 947_png.rf.d242f12e289b17d1ba7dcdc060d00fd1.jpg -> test/ds1_947_png.rf.d242f12e289b17d1ba7dcdc060d00fd1.jpg
#   Copied: 869_png.rf.e03c297ca8712dbcaa7182d0c719afa1.jpg -> test/ds1_869_png.rf.e03c297ca8712dbcaa7182d0c719afa1.jpg
#   Copied: 876_png.rf.a704e7de83bdfbdb04c0ee9f850f9b62.jpg -> test/ds1_876_png.rf.a704e7de83bdfbdb04c0ee9f850f9b62.jpg
#   Copied: 1080_png.rf.389d99681b66201fecaf9d064b145133.jpg -> test/ds1_1080_png.rf.389d99681b66201fecaf9d064b145133.jpg
#   Copied: 657_png.rf.133fdbc6f5b3c40bd5ac247a4dc65db1.jpg -> test/ds1_657_png.rf.133fdbc6f5b3c40bd5ac247a4dc65db1.jpg
#   Copied: 829_png.rf.55cfd657ecbed2a9071d2b1b2cbdd6e8.jpg -> test/ds1_829_png.rf.55cfd657ecbed2a9071d2b1b2cbdd6e8.jpg
#   Copied: 1046_png.rf.abeb31b121e4c9a25edc78879db26651.jpg -> test/ds1_1046_png.rf.abeb31b121e4c9a25edc78879db26651.jpg
#   Copied: 713_png.rf.01a8e40176c46d751f570a528d5c6c97.jpg -> test/ds1_713_png.rf.01a8e40176c46d751f570a528d5c6c97.jpg
#   Copied: 1072_png.rf.75fa1302e433b461082be06ca5b84847.jpg -> test/ds1_1072_png.rf.75fa1302e433b461082be06ca5b84847.jpg
#   Copied: 818_png.rf.184047048b6bf14c65e3e8acbf230a91.jpg -> test/ds1_818_png.rf.184047048b6bf14c65e3e8acbf230a91.jpg
#   Copied: 762_png.rf.c9ac4c677454710fe09d1491f7abb69b.jpg -> test/ds1_762_png.rf.c9ac4c677454710fe09d1491f7abb69b.jpg
#   Copied: 938_png.rf.1729f73660d09f43932b5f79a3ba3ff5.jpg -> test/ds1_938_png.rf.1729f73660d09f43932b5f79a3ba3ff5.jpg
#   Copied: 1028_png.rf.e3a07a8b62a7620a94dba1d040899076.jpg -> test/ds1_1028_png.rf.e3a07a8b62a7620a94dba1d040899076.jpg
#   Copied: 994_png.rf.e2f8304b4c58201a46c23b5ed605f18c.jpg -> test/ds1_994_png.rf.e2f8304b4c58201a46c23b5ed605f18c.jpg
#   Copied: 644_png.rf.925335bca722aac86de268a9ffd3d466.jpg -> test/ds1_644_png.rf.925335bca722aac86de268a9ffd3d466.jpg
#   Copied: 862_png.rf.871836fc48400e4bfe3f66de648dfa90.jpg -> test/ds1_862_png.rf.871836fc48400e4bfe3f66de648dfa90.jpg
#   Copied: 692_png.rf.5700936a6c728e6c56d7c90b7e6fe3e9.jpg -> test/ds1_692_png.rf.5700936a6c728e6c56d7c90b7e6fe3e9.jpg
#   Copied: 702_png.rf.4629d2fe4df152de3ccc32c5fa9dd210.jpg -> test/ds1_702_png.rf.4629d2fe4df152de3ccc32c5fa9dd210.jpg
#   Copied: 701_png.rf.88b18e21b862d24f2ff45cb116fcf554.jpg -> test/ds1_701_png.rf.88b18e21b862d24f2ff45cb116fcf554.jpg
#   Copied: 1059_png.rf.551517eb04ea213b0f906d745b2933bc.jpg -> test/ds1_1059_png.rf.551517eb04ea213b0f906d745b2933bc.jpg
#   Copied: 713_png.rf.9765c9750f1b6002c316516af550ab98.jpg -> test/ds1_713_png.rf.9765c9750f1b6002c316516af550ab98.jpg
#   Copied: 1055_png.rf.f641d0be072edccc2c8888a7be542663.jpg -> test/ds1_1055_png.rf.f641d0be072edccc2c8888a7be542663.jpg
#   Copied: 1060_png.rf.a38273b3d5c9000b37e5da121066dbbd.jpg -> test/ds1_1060_png.rf.a38273b3d5c9000b37e5da121066dbbd.jpg
#   Copied: 686_png.rf.e313360e3944a1f1bf60946d2c5ba81e.jpg -> test/ds1_686_png.rf.e313360e3944a1f1bf60946d2c5ba81e.jpg
#   Copied: 956_png.rf.36110bf16cf0aa24ecdb6d24fcc93da0.jpg -> test/ds1_956_png.rf.36110bf16cf0aa24ecdb6d24fcc93da0.jpg
#   Copied: 1121_png.rf.7e3dde9a973fd9065e0bfe414609bfed.jpg -> test/ds1_1121_png.rf.7e3dde9a973fd9065e0bfe414609bfed.jpg
#   Copied: 1092_png.rf.24c36357fb44f168f82a312696e3faa6.jpg -> test/ds1_1092_png.rf.24c36357fb44f168f82a312696e3faa6.jpg
#   Copied: 882_png.rf.12c3e537f6f23f45737d88192c89d74e.jpg -> test/ds1_882_png.rf.12c3e537f6f23f45737d88192c89d74e.jpg
#   Copied: 690_png.rf.1f7fc008265bf60afb41ab3e183b767a.jpg -> test/ds1_690_png.rf.1f7fc008265bf60afb41ab3e183b767a.jpg
#   Copied: 741_png.rf.13d4e0b111da3d4e7c64e80960f68ac4.jpg -> test/ds1_741_png.rf.13d4e0b111da3d4e7c64e80960f68ac4.jpg
#   Copied: 920_png.rf.11da197cf89585e911f41299b5c453f6.jpg -> test/ds1_920_png.rf.11da197cf89585e911f41299b5c453f6.jpg
#   Copied: 1095_png.rf.b04ffc248f83962a73489d44bbd271d9.jpg -> test/ds1_1095_png.rf.b04ffc248f83962a73489d44bbd271d9.jpg
#   Copied: 994_png.rf.427ed7e9ae6ca34ca38d510d85042523.jpg -> test/ds1_994_png.rf.427ed7e9ae6ca34ca38d510d85042523.jpg
#   Copied: 952_png.rf.172d247aeb862b2a8805b2ae9f2827e4.jpg -> test/ds1_952_png.rf.172d247aeb862b2a8805b2ae9f2827e4.jpg
#   Copied: 1002_png.rf.1d95f291f392a58b970add26bb2fc9c8.jpg -> test/ds1_1002_png.rf.1d95f291f392a58b970add26bb2fc9c8.jpg
#   Copied: 839_png.rf.ca09b7cc7ef2aee02abe4b8d1a5f00b4.jpg -> test/ds1_839_png.rf.ca09b7cc7ef2aee02abe4b8d1a5f00b4.jpg
#   Copied: 997_png.rf.10874f964706c8cb48bf572e1d258e6d.jpg -> test/ds1_997_png.rf.10874f964706c8cb48bf572e1d258e6d.jpg
#   Copied: 651_png.rf.8bdd2129f454a8d6fddb57bcf657b765.jpg -> test/ds1_651_png.rf.8bdd2129f454a8d6fddb57bcf657b765.jpg
#   Copied: 854_png.rf.0ebd6bba61158788adb24a5f94701627.jpg -> test/ds1_854_png.rf.0ebd6bba61158788adb24a5f94701627.jpg
#   Copied: 755_png.rf.4962e4b33d641059a8efc66d5067c17a.jpg -> test/ds1_755_png.rf.4962e4b33d641059a8efc66d5067c17a.jpg
#   Copied: 1125_png.rf.3b4c1b61b6705e3a29f347c0e7a18930.jpg -> test/ds1_1125_png.rf.3b4c1b61b6705e3a29f347c0e7a18930.jpg
#   Copied: 739_png.rf.1ff93f7d8b8f48d347668eb2bf49cb86.jpg -> test/ds1_739_png.rf.1ff93f7d8b8f48d347668eb2bf49cb86.jpg
#   Copied: 825_png.rf.1949743ad4c8ee7f6797369472ef7bec.jpg -> test/ds1_825_png.rf.1949743ad4c8ee7f6797369472ef7bec.jpg
#   Copied: 921_png.rf.a521b9cc2d01e6462a479decb2bb36e3.jpg -> test/ds1_921_png.rf.a521b9cc2d01e6462a479decb2bb36e3.jpg
#   Copied: 894_png.rf.5ea011354c62123a5fd2db3215fa2438.jpg -> test/ds1_894_png.rf.5ea011354c62123a5fd2db3215fa2438.jpg
#   Copied: 932_png.rf.b01f1becd0d61aa8245ac77cc31ce7b1.jpg -> test/ds1_932_png.rf.b01f1becd0d61aa8245ac77cc31ce7b1.jpg
#   Copied: 1113_png.rf.d545c73312fa36230d556d61b9d4fcd9.jpg -> test/ds1_1113_png.rf.d545c73312fa36230d556d61b9d4fcd9.jpg
#   Copied: 836_png.rf.57800307680a3ba3e417b3af94f60f80.jpg -> test/ds1_836_png.rf.57800307680a3ba3e417b3af94f60f80.jpg
#   Copied: page_15.png -> test/ds2_page_15.png
#   Copied: page_26.png -> test/ds2_page_26.png (no label)
#   Copied: page_5.png -> test/ds2_page_5.png
#
# Created merged data.yaml with 1 class(es): [0]
#
# ==================================================
# FINAL MERGED DATASET STATISTICS
# ==================================================
# TRAIN:
#   Total: 735 images, 735 labels
#   Dataset 1: 720 images
#   Dataset 2: 15 images
#   Dataset 2 representation: 2.0%
#
# VAL:
#   Total: 147 images, 147 labels
#   Dataset 1: 144 images
#   Dataset 2: 3 images
#   Dataset 2 representation: 2.0%
#
# TEST:
#   Total: 99 images, 98 labels
#   Dataset 1: 96 images
#   Dataset 2: 3 images
#   Dataset 2 representation: 3.0%
#
# OVERALL TOTAL: 981 images, 980 labels
#
# Dataset merge completed! Output saved to: merged_dataset
